# %% [markdown]
# <a href="https://colab.research.google.com/github/InsightfulSantosh/Web-Scrapping/blob/main/Web%20scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping & Data Handling Challenge**

# %% [markdown]
# ### **Website:**
# JustWatch -  https://www.justwatch.com/in/movies?release_year_from=2000
#
#
# ### **Description:**
#
# JustWatch is a popular platform that allows users to search for movies and TV shows across multiple streaming services like Netflix, Amazon Prime, Hulu, etc. For this assignment, you will be required to scrape movie and TV show data from JustWatch using Selenium, Python, and BeautifulSoup. Extract data from HTML, not by directly calling their APIs. Then, perform data filtering and analysis using Pandas, and finally, save the results to a CSV file.
#
# ### **Tasks:**
#
# **1. Web Scraping:**
#
# Use BeautifulSoup to scrape the following data from JustWatch:
#
#    **a. Movie Information:**
#
#       - Movie title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the movie page on JustWatch
#
#    **b. TV Show Information:**
#
#       - TV show title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the TV show page on JustWatch
#
#   **c. Scope:**
#
# ```
#  ` - Scrape data for at least 50 movies and 50 TV shows.
#    - You can choose the entry point (e.g., starting with popular movies,
#      or a specific genre, etc.) to ensure a diverse dataset.`
#
# ```
#
#
# **2. Data Filtering & Analysis:**
#
#    After scraping the data, use Pandas to perform the following tasks:
#
#    **a. Filter movies and TV shows based on specific criteria:**
#
#    ```
#       - Only include movies and TV shows released in the last 2 years (from the current date).
#       - Only include movies and TV shows with an IMDb rating of 7 or higher.
# ```
#
#    **b. Data Analysis:**
#
#    ```
#       - Calculate the average IMDb rating for the scraped movies and TV shows.
#       - Identify the top 5 genres that have the highest number of available movies and TV shows.
#       - Determine the streaming service with the most significant number of offerings.
#
#    ```
#
# **3. Data Export:**
#
# ```
#    - Dump the filtered and analysed data into a CSV file for further processing and reporting.
#
#    - Keep the CSV file in your Drive Folder and Share the Drive link on the colab while keeping view access with anyone.
# ```
#
# **Submission:**
# ```
# - Submit a link to your Colab made for the assignment.
#
# - The Colab should contain your Python script (.py format only) with clear
#   comments explaining the scraping, filtering, and analysis process.
#
# - Your Code shouldn't have any errors and should be executable at a one go.
#
# - Before Conclusion, Keep your Dataset Drive Link in the Notebook.
# ```
#
#
#
# **Note:**
#
# 1. Properly handle errors and exceptions during web scraping to ensure a robust script.
#
# 2. Make sure your code is well-structured, easy to understand, and follows Python best practices.
#
# 3. The assignment will be evaluated based on the correctness of the scraped data, accuracy of data filtering and analysis, and the overall quality of the Python code.

# %% [markdown]
# # **Start The Project**

# %% [markdown]
# ## **Task 1:- Web Scrapping**

# %%
#Installing all necessary labraries
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)

# %%
#import all necessary labraries
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## **Scrapping Movies Data**

# %%
def fetch_movie_details(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
    }
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the page, status code:", response.status_code
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup


url = 'https://www.justwatch.com/in/movies?release_year_from=2000'
soup=fetch_movie_details(url)

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
movie_links = soup.find_all('a', href=True)
movie_urls = [link['href'] for link in movie_links if '/movie/' in link['href']]

url_list=[]
for x in movie_urls:
    url_list.append('https://www.justwatch.com'+x)

url_list=url_list[:50]
url_list
# Out:
# ['https://www.justwatch.com/in/movie/munjha',
#  'https://www.justwatch.com/in/movie/aavesham-2024',
#  'https://www.justwatch.com/in/movie/project-k',
#  'https://www.justwatch.com/in/movie/family-star',
#  'https://www.justwatch.com/in/movie/the-gangster-the-cop-the-devil',
#  'https://www.justwatch.com/in/movie/hit-man',
#  'https://www.justwatch.com/in/movie/godzilla-minus-one',
#  'https://www.justwatch.com/in/movie/the-fall-guy',
#  'https://www.justwatch.com/in/movie/inside-out',
#  'https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire',
#  'https://www.justwatch.com/in/movie/manjummel-boys',
#  'https://www.justwatch.com/in/movie/furiosa',
#  'https://www.justwatch.com/in/movie/laapataa-ladies',
#  'https://www.justwatch.com/in/movie/rockstar',
#  'https://www.justwatch.com/in/movie/the-crew-2024',
#  'https://www.justwatch.com/in/movie/dune-part-two',
#  'https://www.justwatch.com/in/movie/maidaan',
#  'https://www.justwatch.com/in/movie/civil-war-2024-0',
#  'https://www.justwatch.com/in/movie/maharshi',
#  'https://www.justwatch.com/in/movie/aranmanai-4',
#  'https://www.justwatch.com/in/movie/maharaja-2024',
#  'https://www.justwatch.com/in/movie/premalu',
#  'https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023',
#  'https://www.justwatch.com/in/movie/oppenheimer',
#  'https://www.justwatch.com/in/movie/mad-max-fury-road',
#  'https://www.justwatch.com/in/movie/lovers-2024',
#  'https://www.justwatch.com/in/movie/365-days',
#  'https://www.justwatch.com/in/movie/kung-fu-panda-4',
#  'https://www.justwatch.com/in/movie/challengers',
#  'https://www.justwatch.com/in/movie/sri-2023',
#  'https://www.justwatch.com/in/movie/gangs-of-godavari',
#  'https://www.justwatch.com/in/movie/hereditary',
#  'https://www.justwatch.com/in/movie/maharaj',
#  'https://www.justwatch.com/in/movie/madgaon-express',
#  'https://www.justwatch.com/in/movie/inside-out-2',
#  'https://www.justwatch.com/in/movie/exhuma',
#  'https://www.justwatch.com/in/movie/12th-fail',
#  'https://www.justwatch.com/in/movie/garudan-2024',
#  'https://www.justwatch.com/in/movie/animal-2022',
#  'https://www.justwatch.com/in/movie/je-jatt-vigad-gya',
#  'https://www.justwatch.com/in/movie/salaar',
#  'https://www.justwatch.com/in/movie/hanu-man',
#  'https://www.justwatch.com/in/movie/varshangalkku-shesham',
#  'https://www.justwatch.com/in/movie/aadujeevitham',
#  'https://www.justwatch.com/in/movie/guruvayoor-ambalanadayil',
#  'https://www.justwatch.com/in/movie/dune-2021',
#  'https://www.justwatch.com/in/movie/satyabhama',
#  'https://www.justwatch.com/in/movie/anyone-but-you',
#  'https://www.justwatch.com/in/movie/spider-man-no-way-home',
#  'https://www.justwatch.com/in/movie/mallari']

# %% [markdown]
# ###**Fetch all html movie pages**

# %%
import requests
from bs4 import BeautifulSoup
import time
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# Example: Assuming you have already populated url_list with movie URLs
url_list = url_list

# Define a function to fetch movie pages
def fetch_movie_pages(movie_urls):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        # Add any necessary headers like API keys or tokens here
    }

    all_pages = []

    retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session = requests.Session()
    session.mount('https://', adapter)
    session.mount('http://', adapter)

    for idx, url in enumerate(movie_urls, start=1):
        try:
            response = session.get(url, headers=headers)
            response.raise_for_status()

            if response.status_code == 200:
                soup = BeautifulSoup(response.text, 'html.parser')
                all_pages.append(soup)
                print(f"Fetched page {idx} for {url}")
            else:
                print(f"Failed to fetch page {idx} for {url}. Status code:", response.status_code)

        except requests.exceptions.RequestException as e:
            print(f"Failed to fetch page {idx} for {url}. Error: {e}")

        # Add a small delay to avoid overloading the server
        time.sleep(1)

    return all_pages

# Fetch all movie pages and return as a list of BeautifulSoup objects
html_pages = fetch_movie_pages(url_list)
# Out:
# Fetched page 1 for https://www.justwatch.com/in/movie/munjha
# Fetched page 2 for https://www.justwatch.com/in/movie/aavesham-2024
# Fetched page 3 for https://www.justwatch.com/in/movie/project-k
# Fetched page 4 for https://www.justwatch.com/in/movie/family-star
# Fetched page 5 for https://www.justwatch.com/in/movie/the-gangster-the-cop-the-devil
# Fetched page 6 for https://www.justwatch.com/in/movie/hit-man
# Fetched page 7 for https://www.justwatch.com/in/movie/godzilla-minus-one
# Fetched page 8 for https://www.justwatch.com/in/movie/the-fall-guy
# Fetched page 9 for https://www.justwatch.com/in/movie/inside-out
# Fetched page 10 for https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire
# Fetched page 11 for https://www.justwatch.com/in/movie/manjummel-boys
# Fetched page 12 for https://www.justwatch.com/in/movie/furiosa
# Fetched page 13 for https://www.justwatch.com/in/movie/laapataa-ladies
# Fetched page 14 for https://www.justwatch.com/in/movie/rockstar
# Fetched page 15 for https://www.justwatch.com/in/movie/the-crew-2024
# Fetched page 16 for https://www.justwatch.com/in/movie/dune-part-two
# Fetched page 17 for https://www.justwatch.com/in/movie/maidaan
# Fetched page 18 for https://www.justwatch.com/in/movie/civil-war-2024-0
# Fetched page 19 for https://www.justwatch.com/in/movie/maharshi
# Fetched page 20 for https://www.justwatch.com/in/movie/aranmanai-4
# Fetched page 21 for https://www.justwatch.com/in/movie/maharaja-2024
# Fetched page 22 for https://www.justwatch.com/in/movie/premalu
# Fetched page 23 for https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023
# Fetched page 24 for https://www.justwatch.com/in/movie/oppenheimer
# Fetched page 25 for https://www.justwatch.com/in/movie/mad-max-fury-road
# Fetched page 26 for https://www.justwatch.com/in/movie/lovers-2024
# Fetched page 27 for https://www.justwatch.com/in/movie/365-days
# Fetched page 28 for https://www.justwatch.com/in/movie/kung-fu-panda-4
# Fetched page 29 for https://www.justwatch.com/in/movie/challengers
# Fetched page 30 for https://www.justwatch.com/in/movie/sri-2023
# Fetched page 31 for https://www.justwatch.com/in/movie/gangs-of-godavari
# Fetched page 32 for https://www.justwatch.com/in/movie/hereditary
# Fetched page 33 for https://www.justwatch.com/in/movie/maharaj
# Fetched page 34 for https://www.justwatch.com/in/movie/madgaon-express
# Fetched page 35 for https://www.justwatch.com/in/movie/inside-out-2
# Fetched page 36 for https://www.justwatch.com/in/movie/exhuma
# Fetched page 37 for https://www.justwatch.com/in/movie/12th-fail
# Fetched page 38 for https://www.justwatch.com/in/movie/garudan-2024
# Fetched page 39 for https://www.justwatch.com/in/movie/animal-2022
# Fetched page 40 for https://www.justwatch.com/in/movie/je-jatt-vigad-gya
# Fetched page 41 for https://www.justwatch.com/in/movie/salaar
# Fetched page 42 for https://www.justwatch.com/in/movie/hanu-man
# Fetched page 43 for https://www.justwatch.com/in/movie/varshangalkku-shesham
# Fetched page 44 for https://www.justwatch.com/in/movie/aadujeevitham
# Fetched page 45 for https://www.justwatch.com/in/movie/guruvayoor-ambalanadayil
# Fetched page 46 for https://www.justwatch.com/in/movie/dune-2021
# Fetched page 47 for https://www.justwatch.com/in/movie/satyabhama
# Fetched page 48 for https://www.justwatch.com/in/movie/anyone-but-you
# Fetched page 49 for https://www.justwatch.com/in/movie/spider-man-no-way-home
# Fetched page 50 for https://www.justwatch.com/in/movie/mallari

# %% [markdown]
# ## **Scrapping Movie Title**

# %%
movie_names = []

# Iterating over html_pages
for idx, page in enumerate(html_pages, start=1):
    # Find the div with data-testid="titleBlock"
    title_block_div = page.find('div', attrs={'data-testid': 'titleBlock'})
    if title_block_div:
        # Find the <h1> tag for the movie title
        title_tag = title_block_div.find('h1')
        if title_tag:
            movie_title = title_tag.text.strip()
            movie_names.append(movie_title)
        else:
            movie_names.append(None)  # Add None if movie title is not found
    else:
        movie_names.append(None)  # Add None if title block is not found

# movie_names now contains the list of extracted movie names

movie_names
# Out:
# ['Munjya',
#  'Aavesham',
#  'Kalki 2898 AD',
#  'Family Star',
#  'The Gangster, the Cop, the Devil',
#  'Hit Man',
#  'Godzilla Minus One',
#  'The Fall Guy',
#  'Inside Out',
#  'Godzilla x Kong: The New Empire',
#  'Manjummel Boys',
#  'Furiosa: A Mad Max Saga',
#  'Laapataa Ladies',
#  'Rockstar',
#  'Crew',
#  'Dune: Part Two',
#  'Maidaan',
#  'Civil War',
#  'Maharshi',
#  'Aranmanai 4',
#  'Maharaja',
#  'Premalu',
#  'Bade Miyan Chote Miyan',
#  'Oppenheimer',
#  'Mad Max: Fury Road',
#  'Do Aur Do Pyaar',
#  '365 Days',
#  'Kung Fu Panda 4',
#  'Challengers',
#  'Srikanth',
#  'Gangs of Godavari',
#  'Hereditary',
#  'Maharaj',
#  'Madgaon Express',
#  'Inside Out 2',
#  'Exhuma',
#  '12th Fail',
#  'Garudan',
#  'Animal',
#  'Je Jatt Vigarh Gya',
#  'Salaar',
#  'Hanu-Man',
#  'Varshangalkku Shesham',
#  'The Goat Life',
#  'Guruvayoor Ambalanadayil',
#  'Dune',
#  'Satyabhama',
#  'Anyone But You',
#  'Spider-Man: No Way Home',
#  'Mallari']

# %% [markdown]
# ## **Scrapping release Year**

# %%
release_dates = []

# Iterating over html_pages
for idx, page in enumerate(html_pages, start=1):
    # Find the <span> tag with the class "text-muted" for the release year
    span_tag = page.find('span', class_='text-muted')
    if span_tag:
        release_year = span_tag.text.strip('() ').strip()
        release_dates.append(release_year)
    else:
        release_dates.append(None)  # Add None if release year is not found

# release_dates now contains the list of extracted release years

release_dates
# Out:
# ['2024',
#  '2024',
#  '2024',
#  '2024',
#  '2019',
#  '2024',
#  '2023',
#  '2024',
#  '2015',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2011',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2019',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2015',
#  '2024',
#  '2020',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2018',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2023',
#  '2024',
#  '2023',
#  '2024',
#  '2023',
#  '2024',
#  '2024',
#  '2024',
#  '2024',
#  '2021',
#  '2024',
#  '2023',
#  '2021',
#  '2023']

# %% [markdown]
# ## **Scrapping Genres**

# %%
# Write Your Code here
Generes = []

# Iterating over html_page
for idx, page in enumerate(html_pages, start=1):
    # Find the <span> tag with the class "detail-infos__value" for the Generes
    span_tag = page.find('span',class_='detail-infos__value')
    if span_tag:
        genre = span_tag.text
        Generes.append(genre)
    else:
        Generes.append(None)  # Add None if Generes is not found

# Generes now contains the list of extracted Genere

Generes
# Out:
# ['Comedy, Horror',
#  'Comedy, Action & Adventure',
#  'Drama, Action & Adventure, Fantasy, Science-Fiction, Mystery & Thriller',
#  'Action & Adventure, Drama, Comedy, Romance',
#  'Mystery & Thriller, Action & Adventure, Crime',
#  'Crime, Comedy, Romance',
#  'Horror, Action & Adventure, Drama, Science-Fiction',
#  'Romance, Action & Adventure, Comedy, Drama',
#  'Animation, Kids & Family, Action & Adventure, Drama, Comedy, Fantasy',
#  'Action & Adventure, Fantasy, Science-Fiction, Mystery & Thriller',
#  'Drama, Mystery & Thriller, Action & Adventure',
#  'Mystery & Thriller, Action & Adventure, Science-Fiction',
#  'Comedy, Drama',
#  'Drama, Music & Musical, Romance',
#  'Comedy, Drama',
#  'Science-Fiction, Action & Adventure, Drama',
#  'Sport, Drama, History',
#  'Action & Adventure, Mystery & Thriller, War & Military, Drama',
#  'Action & Adventure, Drama',
#  'Horror, Comedy',
#  'Action & Adventure, Drama, Mystery & Thriller',
#  'Comedy, Romance',
#  'Action & Adventure, Science-Fiction, Mystery & Thriller',
#  'Drama, History',
#  'Action & Adventure, Science-Fiction, Mystery & Thriller',
#  'Drama, Comedy',
#  'Drama, Romance, Made in Europe',
#  'Animation, Action & Adventure, Comedy, Kids & Family, Fantasy',
#  'Drama, Romance, Sport, Comedy',
#  'Drama',
#  'Action & Adventure, Drama, History, Crime',
#  'Mystery & Thriller, Drama, Horror',
#  'Drama, Mystery & Thriller, Crime, History',
#  'Comedy, Drama',
#  'Kids & Family, Action & Adventure, Comedy, Drama, Animation, Fantasy',
#  'Mystery & Thriller, Horror',
#  'Drama',
#  'Action & Adventure, Crime, Mystery & Thriller',
#  'Drama, Action & Adventure, Crime, Mystery & Thriller',
#  'Drama',
#  'Crime, Drama, Mystery & Thriller, Action & Adventure',
#  'Science-Fiction, Fantasy, Action & Adventure, Comedy',
#  'Comedy, Drama, Romance',
#  'Drama',
#  'Comedy',
#  'Science-Fiction, Drama, Action & Adventure',
#  'Crime, Drama, Mystery & Thriller',
#  'Romance, Comedy',
#  'Science-Fiction, Action & Adventure, Fantasy',
#  'Mystery & Thriller, Drama, Horror']

# %% [markdown]
# ###**Scrapping IMDB ratings**

# %%
import requests
from lxml import html

# List of IMDb URLs
urls = url_list

# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

# List to store results
results = []
ratings = []

# XPath expressions for ratings and title
rating_xpaths = [
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[2]/div/div/div[2]/div/span/span/text()',
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[1]/div/div/div[2]/div/span/span/text()'
]


# Loop through the list of URLs
for url in urls:
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()

        tree = html.fromstring(response.content)


        rating = None
        for xpath in rating_xpaths:
            rating = tree.xpath(xpath)
            if rating:
                rating = rating[0]
                break

        results.append((rating))
        ratings.append(rating)
        print(f"IMDb Rating: {rating}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        results.append(("Error fetching title", None))
        ratings.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        results.append(("Error processing title", None))
        ratings.append(None)

# Print results
for rating in results:
    if rating is not None:
        print(f" IMDb Rating: {rating}")
    else:
        print(f" IMDb Rating not available")

# Print all ratings
print("All Ratings:", ratings)
# Out:
# IMDb Rating:  7.2  (14k)
# IMDb Rating:  8.0  (12k)
# IMDb Rating:  7.9  (32k)
# IMDb Rating:  5.2  (3k)
# IMDb Rating:  6.9  (24k)
# IMDb Rating:  6.9  (61k)
# IMDb Rating:  7.7  (130k)
# IMDb Rating:  7.0  (115k)
# IMDb Rating:  8.1  (805k)
# IMDb Rating:  6.2  (81k)
# IMDb Rating:  8.3  (18k)
# IMDb Rating:  7.7  (120k)
# IMDb Rating:  8.5  (34k)
# IMDb Rating:  7.7  (49k)
# IMDb Rating:  5.9  (34k)
# IMDb Rating:  8.6  (467k)
# IMDb Rating:  8.1  (16k)
# IMDb Rating:  7.2  (125k)
# IMDb Rating:  7.2  (9k)
# IMDb Rating:  5.2  (1k)
# IMDb Rating:  8.6  (3k)
# IMDb Rating:  7.9  (12k)
# IMDb Rating:  4.1  (37k)
# IMDb Rating:  8.3  (763k)
# IMDb Rating:  8.1  (1m)
# IMDb Rating:  6.3  (5k)
# IMDb Rating:  3.3  (99k)
# IMDb Rating:  6.3  (45k)
# IMDb Rating:  7.3  (75k)
# IMDb Rating:  7.7  (7k)
# IMDb Rating:  5.1
# IMDb Rating:  7.3  (385k)
# IMDb Rating:  6.4  (6k)
# IMDb Rating:  7.1  (35k)
# IMDb Rating:  7.9  (61k)
# IMDb Rating:  6.9  (10k)
# IMDb Rating:  8.9  (120k)
# IMDb Rating:  7.3  (1k)
# IMDb Rating:  6.2  (93k)
# IMDb Rating:  4.7
# IMDb Rating:  6.5  (66k)
# IMDb Rating:  7.9  (25k)
# IMDb Rating:  6.7  (2k)
# IMDb Rating:  8.6  (7k)
# IMDb Rating:  6.7  (1k)
# IMDb Rating:  8.0  (884k)
# IMDb Rating:  7.0
# IMDb Rating:  6.1  (98k)
# IMDb Rating:  8.2  (891k)
# IMDb Rating:  6.3
#  IMDb Rating:  7.2  (14k)
#  IMDb Rating:  8.0  (12k)
#  IMDb Rating:  7.9  (32k)
#  IMDb Rating:  5.2  (3k)
#  IMDb Rating:  6.9  (24k)
#  IMDb Rating:  6.9  (61k)
#  IMDb Rating:  7.7  (130k)
#  IMDb Rating:  7.0  (115k)
#  IMDb Rating:  8.1  (805k)
#  IMDb Rating:  6.2  (81k)
#  IMDb Rating:  8.3  (18k)
#  IMDb Rating:  7.7  (120k)
#  IMDb Rating:  8.5  (34k)
#  IMDb Rating:  7.7  (49k)
#  IMDb Rating:  5.9  (34k)
#  IMDb Rating:  8.6  (467k)
#  IMDb Rating:  8.1  (16k)
#  IMDb Rating:  7.2  (125k)
#  IMDb Rating:  7.2  (9k)
#  IMDb Rating:  5.2  (1k)
#  IMDb Rating:  8.6  (3k)
#  IMDb Rating:  7.9  (12k)
#  IMDb Rating:  4.1  (37k)
#  IMDb Rating:  8.3  (763k)
#  IMDb Rating:  8.1  (1m)
#  IMDb Rating:  6.3  (5k)
#  IMDb Rating:  3.3  (99k)
#  IMDb Rating:  6.3  (45k)
#  IMDb Rating:  7.3  (75k)
#  IMDb Rating:  7.7  (7k)
#  IMDb Rating:  5.1
#  IMDb Rating:  7.3  (385k)
#  IMDb Rating:  6.4  (6k)
#  IMDb Rating:  7.1  (35k)
#  IMDb Rating:  7.9  (61k)
#  IMDb Rating:  6.9  (10k)
#  IMDb Rating:  8.9  (120k)
#  IMDb Rating:  7.3  (1k)
#  IMDb Rating:  6.2  (93k)
#  IMDb Rating:  4.7
#  IMDb Rating:  6.5  (66k)
#  IMDb Rating:  7.9  (25k)
#  IMDb Rating:  6.7  (2k)
#  IMDb Rating:  8.6  (7k)
#  IMDb Rating:  6.7  (1k)
#  IMDb Rating:  8.0  (884k)
#  IMDb Rating:  7.0
#  IMDb Rating:  6.1  (98k)
#  IMDb Rating:  8.2  (891k)
#  IMDb Rating:  6.3
# All Ratings: [' 7.2  (14k) ', ' 8.0  (12k) ', ' 7.9  (32k) ', ' 5.2  (3k) ', ' 6.9  (24k) ', ' 6.9  (61k) ', ' 7.7  (130k) ', ' 7.0  (115k) ', ' 8.1  (805k) ', ' 6.2  (81k) ', ' 8.3  (18k) ', ' 7.7  (120k) ', ' 8.5  (34k) ', ' 7.7  (49k) ', ' 5.9  (34k) ', ' 8.6  (467k) ', ' 8.1  (16k) ', ' 7.2  (125k) ', ' 7.2  (9k) ', ' 5.2  (1k) ', ' 8.6  (3k) ', ' 7.9  (12k) ', ' 4.1  (37k) ', ' 8.3  (763k) ', ' 8.1  (1m) ', ' 6.3  (5k) ', ' 3.3  (99k) ', ' 6.3  (45k) ', ' 7.3  (75k) ', ' 7.7  (7k) ', ' 5.1  ', ' 7.3  (385k) ', ' 6.4  (6k) ', ' 7.1  (35k) ', ' 7.9  (61k) ', ' 6.9  (10k) ', ' 8.9  (120k) ', ' 7.3  (1k) ', ' 6.2  (93k) ', ' 4.7  ', ' 6.5  (66k) ', ' 7.9  (25k) ', ' 6.7  (2k) ', ' 8.6  (7k) ', ' 6.7  (1k) ', ' 8.0  (884k) ', ' 7.0  ', ' 6.1  (98k) ', ' 8.2  (891k) ', ' 6.3  ']

# %% [markdown]
# ## **Scrapping Runtime/Duration**

# %%
import requests
from lxml import html

# List of IMDb URLs
urls = url_list

# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

# List to store results
results = []
runtimes = []

# XPath expressions for runtime
runtime_xpaths = [
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[3]/div/text()',
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[4]/div/text()'
]

# Loop through the list of URLs
for url in urls:
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()

        tree = html.fromstring(response.content)

        runtime = None
        for xpath in runtime_xpaths:
            runtime = tree.xpath(xpath)
            if runtime:
                runtime = runtime[0]
                break

        results.append(runtime)
        runtimes.append(runtime)
        print(f"Runtime: {runtime}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        results.append(None)
        runtimes.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        results.append(None)
        runtimes.append(None)

# Print results
for runtime in results:
    if runtime is not None:
        print(f"Runtime: {runtime}")
    else:
        print(f"Runtime not available")

# Print all runtimes
print("All Runtimes:", runtimes)
# Out:
# Runtime: 2h 3min
# Runtime: 2h 38min
# Runtime: 3h 1min
# Runtime: 2h 39min
# Runtime: 1h 50min
# Runtime: 1h 56min
# Runtime: 2h 5min
# Runtime: 2h 6min
# Runtime: 1h 35min
# Runtime: 1h 55min
# Runtime: 2h 15min
# Runtime: 2h 28min
# Runtime: 2h 2min
# Runtime: 2h 39min
# Runtime: 1h 58min
# Runtime: 2h 47min
# Runtime: 3h 1min
# Runtime: 1h 49min
# Runtime: 2h 56min
# Runtime: 2h 28min
# Runtime: 2h 30min
# Runtime: 2h 36min
# Runtime: 2h 44min
# Runtime: 3h 0min
# Runtime: 2h 1min
# Runtime: 2h 20min
# Runtime: 1h 54min
# Runtime: 1h 34min
# Runtime: 2h 12min
# Runtime: 2h 14min
# Runtime: 2h 23min
# Runtime: 2h 6min
# Runtime: 2h 12min
# Runtime: 2h 23min
# Runtime: 1h 37min
# Runtime: 2h 14min
# Runtime: 2h 26min
# Runtime: 2h 13min
# Runtime: 3h 21min
# Runtime: 2h 12min
# Runtime: 2h 55min
# Runtime: 2h 39min
# Runtime: 2h 46min
# Runtime: 2h 52min
# Runtime: 2h 12min
# Runtime: 2h 35min
# Runtime: 2h 12min
# Runtime: 1h 44min
# Runtime: 2h 28min
# Runtime: 2h 9min
# Runtime: 2h 3min
# Runtime: 2h 38min
# Runtime: 3h 1min
# Runtime: 2h 39min
# Runtime: 1h 50min
# Runtime: 1h 56min
# Runtime: 2h 5min
# Runtime: 2h 6min
# Runtime: 1h 35min
# Runtime: 1h 55min
# Runtime: 2h 15min
# Runtime: 2h 28min
# Runtime: 2h 2min
# Runtime: 2h 39min
# Runtime: 1h 58min
# Runtime: 2h 47min
# Runtime: 3h 1min
# Runtime: 1h 49min
# Runtime: 2h 56min
# Runtime: 2h 28min
# Runtime: 2h 30min
# Runtime: 2h 36min
# Runtime: 2h 44min
# Runtime: 3h 0min
# Runtime: 2h 1min
# Runtime: 2h 20min
# Runtime: 1h 54min
# Runtime: 1h 34min
# Runtime: 2h 12min
# Runtime: 2h 14min
# Runtime: 2h 23min
# Runtime: 2h 6min
# Runtime: 2h 12min
# Runtime: 2h 23min
# Runtime: 1h 37min
# Runtime: 2h 14min
# Runtime: 2h 26min
# Runtime: 2h 13min
# Runtime: 3h 21min
# Runtime: 2h 12min
# Runtime: 2h 55min
# Runtime: 2h 39min
# Runtime: 2h 46min
# Runtime: 2h 52min
# Runtime: 2h 12min
# Runtime: 2h 35min
# Runtime: 2h 12min
# Runtime: 1h 44min
# Runtime: 2h 28min
# Runtime: 2h 9min
# All Runtimes: ['2h 3min', '2h 38min', '3h 1min', '2h 39min', '1h 50min', '1h 56min', '2h 5min', '2h 6min', '1h 35min', '1h 55min', '2h 15min', '2h 28min', '2h 2min', '2h 39min', '1h 58min', '2h 47min', '3h 1min', '1h 49min', '2h 56min', '2h 28min', '2h 30min', '2h 36min', '2h 44min', '3h 0min', '2h 1min', '2h 20min', '1h 54min', '1h 34min', '2h 12min', '2h 14min', '2h 23min', '2h 6min', '2h 12min', '2h 23min', '1h 37min', '2h 14min', '2h 26min', '2h 13min', '3h 21min', '2h 12min', '2h 55min', '2h 39min', '2h 46min', '2h 52min', '2h 12min', '2h 35min', '2h 12min', '1h 44min', '2h 28min', '2h 9min']

# %% [markdown]
# ## **Scrapping Age Rating**

# %%
import requests
from lxml import html

# List of IMDb URLs
urls = url_list
# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

# List to store results
age_ratings = []

# XPath expression for age rating
age_rating_xpath = '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[5]/div/text()'

# Loop through the list of URLs
for url in urls:
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()

        tree = html.fromstring(response.content)

        age_rating = tree.xpath(age_rating_xpath)
        age_rating = age_rating[0] if age_rating else None

        if age_rating in ["UA", "A", "U"]:
            age_ratings.append(age_rating)
            print(f"Age Rating: {age_rating}")
        else:
            age_ratings.append(None)
            print("Age Rating not in ['UA', 'A', 'U']")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        age_ratings.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        age_ratings.append(None)

# Print all age ratings
print("All Age Ratings:", age_ratings)
# Out:
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: A
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: U
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: UA
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: UA
# Age Rating: UA
# Age Rating: UA
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: UA
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: U
# Age Rating: UA
# Age Rating: UA
# Age Rating: A
# Age Rating: UA
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: U
# Age Rating: UA
# Age Rating: A
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: UA
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: UA
# Age Rating: A
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: A
# Age Rating: UA
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: UA
# Age Rating: UA
# Age Rating: A
# Age Rating: UA
# Age Rating: A
# All Age Ratings: [None, None, None, None, None, 'A', None, None, 'U', None, 'UA', None, 'UA', 'UA', 'UA', None, None, None, 'UA', None, None, 'U', 'UA', 'UA', 'A', 'UA', None, None, None, 'U', 'UA', 'A', None, 'UA', None, None, None, 'UA', 'A', None, 'A', 'UA', None, None, None, 'UA', 'UA', 'A', 'UA', 'A']

# %% [markdown]
# ## **Fetching Production Countries Details**

# %%
import requests
from lxml import html

# List of IMDb URLs
urls = url_list

# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

# List to store results
results = []
production_countries = []

# XPath expressions for production country
production_country_xpaths = [
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[6]/div/text()',
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[5]/div/text()',
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[4]/div/text()'
]

# Loop through the list of URLs
for url in urls:
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()

        tree = html.fromstring(response.content)

        production_country = None
        for xpath in production_country_xpaths:
            production_country = tree.xpath(xpath)
            if production_country:
                production_country = production_country[0].strip()
                break

        results.append(production_country)
        production_countries.append(production_country)
        print(f"Production Country: {production_country}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        results.append(None)
        production_countries.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        results.append(None)
        production_countries.append(None)

# Print results
for production_country in results:
    if production_country is not None:
        print(f"Production Country: {production_country}")
    else:
        print(f"Production Country not available")

# Print all production countries
print("All Production Countries:", production_countries)
# Out:
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: South Korea
# Production Country: United States
# Production Country: Japan
# Production Country: Canada, United States, Australia
# Production Country: United States
# Production Country: United States, Australia
# Production Country: India
# Production Country: Australia, United States
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: United States, United Kingdom
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: United Kingdom, United States
# Production Country: Australia, United States
# Production Country: India
# Production Country: Poland
# Production Country: United States
# Production Country: Italy, United States
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: South Korea
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: United States, India
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: Philippines
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: South Korea
# Production Country: United States
# Production Country: Japan
# Production Country: Canada, United States, Australia
# Production Country: United States
# Production Country: United States, Australia
# Production Country: India
# Production Country: Australia, United States
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: United States, United Kingdom
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: United Kingdom, United States
# Production Country: Australia, United States
# Production Country: India
# Production Country: Poland
# Production Country: United States
# Production Country: Italy, United States
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: South Korea
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: India
# Production Country: United States, India
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: Philippines
# All Production Countries: ['India', 'India', 'India', 'India', 'South Korea', 'United States', 'Japan', 'Canada, United States, Australia', 'United States', 'United States, Australia', 'India', 'Australia, United States', 'India', 'India', 'India', 'United States', 'India', 'United States, United Kingdom', 'India', 'India', 'India', 'India', 'India', 'United Kingdom, United States', 'Australia, United States', 'India', 'Poland', 'United States', 'Italy, United States', 'India', 'India', 'United States', 'India', 'India', 'United States', 'South Korea', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'United States, India', 'India', 'United States', 'India', 'United States', 'United States', 'Philippines']

# %% [markdown]
# ## **Fetching Streaming Service Details**

# %%
from bs4 import BeautifulSoup
import requests

# Example URL list (replace with your actual URLs)
url_list = url_list

# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

# List to store streaming service values
stream = []  # List to store streaming service values

# Loop through the list of URLs, up to a maximum of 50 URLs
for url in url_list:
    try:
        # Send a GET request, passing headers
        response = session.get(url, headers=headers)
        response.raise_for_status()

        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the first <img> tag with class 'offer__icon'
        icon = soup.find('img', class_='offer__icon')

        # Extract the 'alt' attribute (streaming service name)
        if icon:
            alt = icon.get('alt')
            stream.append(alt)
            print(f"URL: {url}")
            print(f"Streaming Service: {alt}")
        else:
            print(f"No streaming service found for URL: {url}")
            stream.append("No streaming service found")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        stream.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        stream.append(None)

# Print all streaming service values collected
print("All Streaming Services:", stream)
# Out:
# URL: https://www.justwatch.com/in/movie/munjha
# Streaming Service: Bookmyshow
# URL: https://www.justwatch.com/in/movie/aavesham-2024
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/project-k
# Streaming Service: Bookmyshow
# URL: https://www.justwatch.com/in/movie/family-star
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/the-gangster-the-cop-the-devil
# Streaming Service: Lionsgate Play
# URL: https://www.justwatch.com/in/movie/hit-man
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/godzilla-minus-one
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/the-fall-guy
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/inside-out
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/godzilla-x-kong-the-new-empire
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/manjummel-boys
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/movie/furiosa
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/laapataa-ladies
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/rockstar
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/the-crew-2024
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/dune-part-two
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/maidaan
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/civil-war-2024-0
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/maharshi
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/aranmanai-4
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/movie/maharaja-2024
# Streaming Service: Bookmyshow
# URL: https://www.justwatch.com/in/movie/premalu
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/movie/bade-miyan-chote-miyan-2023
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/oppenheimer
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/mad-max-fury-road
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/lovers-2024
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/movie/365-days
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/kung-fu-panda-4
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/challengers
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/sri-2023
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/gangs-of-godavari
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/hereditary
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/maharaj
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/madgaon-express
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/inside-out-2
# Streaming Service: Bookmyshow
# No streaming service found for URL: https://www.justwatch.com/in/movie/exhuma
# URL: https://www.justwatch.com/in/movie/12th-fail
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/movie/garudan-2024
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/animal-2022
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/je-jatt-vigad-gya
# Streaming Service: Bookmyshow
# URL: https://www.justwatch.com/in/movie/salaar
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/movie/hanu-man
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/movie/varshangalkku-shesham
# Streaming Service: Sony Liv
# No streaming service found for URL: https://www.justwatch.com/in/movie/aadujeevitham
# URL: https://www.justwatch.com/in/movie/guruvayoor-ambalanadayil
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/movie/dune-2021
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/satyabhama
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/movie/anyone-but-you
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/spider-man-no-way-home
# Streaming Service: Apple TV
# URL: https://www.justwatch.com/in/movie/mallari
# Streaming Service: Netflix
# All Streaming Services: ['Bookmyshow', 'Amazon Prime Video', 'Bookmyshow', 'Amazon Prime Video', 'Lionsgate Play', 'Netflix', 'Netflix', 'Apple TV', 'Apple TV', 'Apple TV', 'Hotstar', 'Apple TV', 'Netflix', 'Apple TV', 'Netflix', 'Apple TV', 'Amazon Prime Video', 'Amazon Prime Video', 'Amazon Prime Video', 'Hotstar', 'Bookmyshow', 'Hotstar', 'Netflix', 'Apple TV', 'Amazon Prime Video', 'Hotstar', 'Netflix', 'Apple TV', 'Apple TV', 'Netflix', 'Netflix', 'Amazon Prime Video', 'Netflix', 'Amazon Prime Video', 'Bookmyshow', 'No streaming service found', 'Hotstar', 'Amazon Prime Video', 'Netflix', 'Bookmyshow', 'Netflix', 'Hotstar', 'Sony Liv', 'No streaming service found', 'Hotstar', 'Apple TV', 'Amazon Prime Video', 'Apple TV', 'Apple TV', 'Netflix']

# %%
len(stream)
# Out:
# 50

# %% [markdown]
# ## **Now Creating Movies DataFrame**

# %%
# Write Your Code here
import pandas as pd

# Assuming 'movie_names' and 'release_dates' are lists of equal length (50)
movies=pd.DataFrame({'Movie Name': movie_names, 'release_dates': release_dates,'Generes': Generes,"IMDB_ratings":ratings,"runtimes":runtimes,
              "age_ratings":age_ratings,"production_countries":production_countries,"streaming service":stream,"link":url_list})

movies.to_csv('movies.csv', index=False)

# %%
movies.head()
# Out:
#                          Movie Name release_dates  \
# 0                            Munjya          2024
# 1                          Aavesham          2024
# 2                     Kalki 2898 AD          2024
# 3                       Family Star          2024
# 4  The Gangster, the Cop, the Devil          2019
#
#                                              Generes   IMDB_ratings runtimes  \
# 0  Crime, Action & Adventure, Drama, Mystery & Th...    8.5  (83k)     50min
# 1                                      Drama, Comedy    9.0  (94k)     35min
# 2  Romance, Action & Adventure, Drama, Fantasy, S...   8.4  (400k)     59min
# 3  Action & Adventure, Science-Fiction, Comedy, C...   8.7  (682k)   1h 2min
# 4                       Kids & Family, Comedy, Drama    9.1  (23k)     30min
#
#   age_ratings production_countries   streaming service  \
# 0        None                India  Amazon Prime Video
# 1        None                India  Amazon Prime Video
# 2           A        United States          Jio Cinema
# 3           A        United States  Amazon Prime Video
# 4        None                India            Sony Liv
#
#                                                 link
# 0      https://www.justwatch.com/in/tv-show/mirzapur
# 1     https://www.justwatch.com/in/tv-show/panchayat
# 2  https://www.justwatch.com/in/tv-show/house-of-...
# 3      https://www.justwatch.com/in/tv-show/the-boys
# 4        https://www.justwatch.com/in/tv-show/gullak

# %% [markdown]
# ## **Scraping TV  Show Data**

# %%
def fetch_movie_details(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'
    }
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        return "Failed to retrieve the page, status code:", response.status_code
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup


url = 'https://www.justwatch.com/in/tv-shows?release_year_from=2000'
soup=fetch_movie_details(url)

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
tv_links = soup.find_all('a', href=True)
tv_urls = [link['href'] for link in tv_links if '/tv-show/' in link['href']]

url_list=[]
for x in tv_urls:
    url_list.append('https://www.justwatch.com'+x)

url_list=url_list[:50]
url_list
# Out:
# ['https://www.justwatch.com/in/tv-show/mirzapur',
#  'https://www.justwatch.com/in/tv-show/panchayat',
#  'https://www.justwatch.com/in/tv-show/house-of-the-dragon',
#  'https://www.justwatch.com/in/tv-show/the-boys',
#  'https://www.justwatch.com/in/tv-show/gullak',
#  'https://www.justwatch.com/in/tv-show/kota-factory',
#  'https://www.justwatch.com/in/tv-show/bridgerton',
#  'https://www.justwatch.com/in/tv-show/game-of-thrones',
#  'https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba',
#  'https://www.justwatch.com/in/tv-show/shogun-2024',
#  'https://www.justwatch.com/in/tv-show/raising-voices',
#  'https://www.justwatch.com/in/tv-show/the-bear',
#  'https://www.justwatch.com/in/tv-show/heeramandi',
#  'https://www.justwatch.com/in/tv-show/apharan',
#  'https://www.justwatch.com/in/tv-show/dark-matter-2024',
#  'https://www.justwatch.com/in/tv-show/presumed-innocent',
#  'https://www.justwatch.com/in/tv-show/fargo',
#  'https://www.justwatch.com/in/tv-show/aashram',
#  'https://www.justwatch.com/in/tv-show/attack-on-titan',
#  'https://www.justwatch.com/in/tv-show/sunflower-2021',
#  'https://www.justwatch.com/in/tv-show/farzi',
#  'https://www.justwatch.com/in/tv-show/supacell',
#  'https://www.justwatch.com/in/tv-show/3-body-problem',
#  'https://www.justwatch.com/in/tv-show/the-good-doctor',
#  'https://www.justwatch.com/in/tv-show/fallout',
#  'https://www.justwatch.com/in/tv-show/bigg-boss-ott',
#  'https://www.justwatch.com/in/tv-show/evil',
#  'https://www.justwatch.com/in/tv-show/the-acolyte',
#  'https://www.justwatch.com/in/tv-show/jamnapaar',
#  'https://www.justwatch.com/in/tv-show/mastram',
#  'https://www.justwatch.com/in/tv-show/stranger-things',
#  'https://www.justwatch.com/in/tv-show/breaking-bad',
#  'https://www.justwatch.com/in/tv-show/maxton-hall-the-world-between-us',
#  'https://www.justwatch.com/in/tv-show/from',
#  'https://www.justwatch.com/in/tv-show/paperhouse',
#  'https://www.justwatch.com/in/tv-show/joko-anwars-nightmares-and-daydreams',
#  'https://www.justwatch.com/in/tv-show/the-family-man',
#  'https://www.justwatch.com/in/tv-show/mtv-splitsvilla',
#  'https://www.justwatch.com/in/tv-show/tulsa-king',
#  'https://www.justwatch.com/in/tv-show/the-orville',
#  'https://www.justwatch.com/in/tv-show/asur',
#  'https://www.justwatch.com/in/tv-show/the-rookie',
#  'https://www.justwatch.com/in/tv-show/true-detective',
#  'https://www.justwatch.com/in/tv-show/the-mole-2022',
#  'https://www.justwatch.com/in/tv-show/my-demon',
#  'https://www.justwatch.com/in/tv-show/jujutsu-kaisen',
#  'https://www.justwatch.com/in/tv-show/peaky-blinders',
#  'https://www.justwatch.com/in/tv-show/bigg-boss',
#  'https://www.justwatch.com/in/tv-show/the-legend-of-hanuman',
#  'https://www.justwatch.com/in/tv-show/kaiju-no-8']

# %%
import requests
from bs4 import BeautifulSoup
import time
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry

# Example: Assuming you have already populated url_list with movie URLs
url_list = url_list

# Define a function to fetch movie pages
def fetch_movie_pages(tv_urls):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
        # Add any necessary headers like API keys or tokens here
    }

    all_pages = []

    retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session = requests.Session()
    session.mount('https://', adapter)
    session.mount('http://', adapter)

    for idx, url in enumerate(tv_urls, start=1):
        try:
            response = session.get(url, headers=headers)
            response.raise_for_status()

            if response.status_code == 200:
                soup = BeautifulSoup(response.text, 'html.parser')
                all_pages.append(soup)
                print(f"Fetched page {idx} for {url}")
            else:
                print(f"Failed to fetch page {idx} for {url}. Status code:", response.status_code)

        except requests.exceptions.RequestException as e:
            print(f"Failed to fetch page {idx} for {url}. Error: {e}")

        # Add a small delay to avoid overloading the server
        time.sleep(1)

    return all_pages

# Fetch all movie pages and return as a list of BeautifulSoup objects
html_pages2 = fetch_movie_pages(url_list)
# Out:
# Fetched page 1 for https://www.justwatch.com/in/tv-show/mirzapur
# Fetched page 2 for https://www.justwatch.com/in/tv-show/panchayat
# Fetched page 3 for https://www.justwatch.com/in/tv-show/house-of-the-dragon
# Fetched page 4 for https://www.justwatch.com/in/tv-show/the-boys
# Fetched page 5 for https://www.justwatch.com/in/tv-show/gullak
# Fetched page 6 for https://www.justwatch.com/in/tv-show/kota-factory
# Fetched page 7 for https://www.justwatch.com/in/tv-show/bridgerton
# Fetched page 8 for https://www.justwatch.com/in/tv-show/game-of-thrones
# Fetched page 9 for https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba
# Fetched page 10 for https://www.justwatch.com/in/tv-show/shogun-2024
# Fetched page 11 for https://www.justwatch.com/in/tv-show/raising-voices
# Fetched page 12 for https://www.justwatch.com/in/tv-show/the-bear
# Fetched page 13 for https://www.justwatch.com/in/tv-show/heeramandi
# Fetched page 14 for https://www.justwatch.com/in/tv-show/apharan
# Fetched page 15 for https://www.justwatch.com/in/tv-show/dark-matter-2024
# Fetched page 16 for https://www.justwatch.com/in/tv-show/presumed-innocent
# Fetched page 17 for https://www.justwatch.com/in/tv-show/fargo
# Fetched page 18 for https://www.justwatch.com/in/tv-show/aashram
# Fetched page 19 for https://www.justwatch.com/in/tv-show/attack-on-titan
# Fetched page 20 for https://www.justwatch.com/in/tv-show/sunflower-2021
# Fetched page 21 for https://www.justwatch.com/in/tv-show/farzi
# Fetched page 22 for https://www.justwatch.com/in/tv-show/supacell
# Fetched page 23 for https://www.justwatch.com/in/tv-show/3-body-problem
# Fetched page 24 for https://www.justwatch.com/in/tv-show/the-good-doctor
# Fetched page 25 for https://www.justwatch.com/in/tv-show/fallout
# Fetched page 26 for https://www.justwatch.com/in/tv-show/bigg-boss-ott
# Fetched page 27 for https://www.justwatch.com/in/tv-show/evil
# Fetched page 28 for https://www.justwatch.com/in/tv-show/the-acolyte
# Fetched page 29 for https://www.justwatch.com/in/tv-show/jamnapaar
# Fetched page 30 for https://www.justwatch.com/in/tv-show/mastram
# Fetched page 31 for https://www.justwatch.com/in/tv-show/stranger-things
# Fetched page 32 for https://www.justwatch.com/in/tv-show/breaking-bad
# Fetched page 33 for https://www.justwatch.com/in/tv-show/maxton-hall-the-world-between-us
# Fetched page 34 for https://www.justwatch.com/in/tv-show/from
# Fetched page 35 for https://www.justwatch.com/in/tv-show/paperhouse
# Fetched page 36 for https://www.justwatch.com/in/tv-show/joko-anwars-nightmares-and-daydreams
# Fetched page 37 for https://www.justwatch.com/in/tv-show/the-family-man
# Fetched page 38 for https://www.justwatch.com/in/tv-show/mtv-splitsvilla
# Fetched page 39 for https://www.justwatch.com/in/tv-show/tulsa-king
# Fetched page 40 for https://www.justwatch.com/in/tv-show/the-orville
# Fetched page 41 for https://www.justwatch.com/in/tv-show/asur
# Fetched page 42 for https://www.justwatch.com/in/tv-show/the-rookie
# Fetched page 43 for https://www.justwatch.com/in/tv-show/true-detective
# Fetched page 44 for https://www.justwatch.com/in/tv-show/the-mole-2022
# Fetched page 45 for https://www.justwatch.com/in/tv-show/my-demon
# Fetched page 46 for https://www.justwatch.com/in/tv-show/jujutsu-kaisen
# Fetched page 47 for https://www.justwatch.com/in/tv-show/peaky-blinders
# Fetched page 48 for https://www.justwatch.com/in/tv-show/bigg-boss
# Fetched page 49 for https://www.justwatch.com/in/tv-show/the-legend-of-hanuman
# Fetched page 50 for https://www.justwatch.com/in/tv-show/kaiju-no-8

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
show_names = []

# Iterating over html_pages2
for page in html_pages2:
    # Find the div with class 'title-block' (assuming there is only one)
    title_div = page.find('div', class_='title-block')

    if title_div:
        # Extract the text of the span tag within the div
        show_name = title_div.find('h1').text.strip()
        show_names.append(show_name)
    else:
        show_names.append(None)

show_names
# Out:
# ['Mirzapur',
#  'Panchayat',
#  'House of the Dragon',
#  'The Boys',
#  'Gullak',
#  'Kota Factory',
#  'Bridgerton',
#  'Game of Thrones',
#  'Demon Slayer: Kimetsu no Yaiba',
#  'Shōgun',
#  'Raising Voices',
#  'The Bear',
#  'Heeramandi: The Diamond Bazaar',
#  'Dark Matter',
#  'Apharan',
#  'Presumed Innocent',
#  'Fargo',
#  'Aashram',
#  'Attack on Titan',
#  'Sunflower',
#  'Fallout',
#  'The Acolyte',
#  'Farzi',
#  'Supacell',
#  'The Good Doctor',
#  '3 Body Problem',
#  'Bigg Boss OTT',
#  'Evil',
#  'Maxton Hall: The World Between Us',
#  'Jamnapaar',
#  'Stranger Things',
#  'From',
#  'Breaking Bad',
#  'Mastram',
#  'Money Heist',
#  'Asur: Welcome to Your Dark Side',
#  "Joko Anwar's Nightmares and Daydreams",
#  'The Family Man',
#  'Tulsa King',
#  'MTV Splitsvilla',
#  'The Orville',
#  'The Rookie',
#  'True Detective',
#  'Jujutsu Kaisen',
#  'My Demon',
#  'Kaiju No. 8',
#  'Peaky Blinders',
#  'Bigg Boss',
#  'The Legend of Hanuman',
#  'The Mole']

# %% [markdown]
# ## **Fetching Release Year**

# %%
release_years = []

# Iterating over html_pages2
for page in html_pages2:
    # Find the div with class 'title-block' (assuming there is only one)
    title_div = page.find('div', class_='title-block')

    if title_div:
        # Extract the text of the span tag within the div (assuming release year is within this structure)
        release_year = title_div.find('span').text.strip()
        release_years.append(release_year)
    else:
        release_years.append(None)

release_years
# Out:
# ['(2018)',
#  '(2020)',
#  '(2022)',
#  '(2019)',
#  '(2019)',
#  '(2019)',
#  '(2020)',
#  '(2011)',
#  '(2019)',
#  '(2024)',
#  '(2024)',
#  '(2022)',
#  '(2024)',
#  '(2024)',
#  '(2018)',
#  '(2024)',
#  '(2014)',
#  '(2020)',
#  '(2013)',
#  '(2021)',
#  '(2024)',
#  '(2024)',
#  '(2023)',
#  '(2024)',
#  '(2017)',
#  '(2024)',
#  '(2021)',
#  '(2019)',
#  '(2024)',
#  '(2024)',
#  '(2016)',
#  '(2022)',
#  '(2008)',
#  '(2020)',
#  '(2017)',
#  '(2020)',
#  '(2024)',
#  '(2019)',
#  '(2022)',
#  '(2008)',
#  '(2017)',
#  '(2018)',
#  '(2014)',
#  '(2020)',
#  '(2023)',
#  '(2024)',
#  '(2013)',
#  '(2006)',
#  '(2021)',
#  '(2022)']

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Write Your Code here

Generes = []

# Iterating over html_page
for idx, page in enumerate(html_pages2, start=1):
    # Find the <span> tag with the class "detail-infos__value" for the Generes
    span_tag = page.find('span',class_='detail-infos__value')
    if span_tag:
        genre = span_tag.text
        Generes.append(genre)
    else:
        Generes.append(None)  # Add None if Generes is not found

# Generes now contains the list of extracted Genere

Generes
# Out:
# ['Crime, Action & Adventure, Drama, Mystery & Thriller',
#  'Drama, Comedy',
#  'Romance, Action & Adventure, Drama, Fantasy, Science-Fiction',
#  'Action & Adventure, Science-Fiction, Comedy, Crime, Drama',
#  'Kids & Family, Comedy, Drama',
#  'Comedy, Drama',
#  'Drama, Romance',
#  'Action & Adventure, Drama, Fantasy, Science-Fiction',
#  'Animation, Action & Adventure, Fantasy, Mystery & Thriller',
#  'War & Military, Drama, History',
#  'Drama',
#  'Drama, Comedy',
#  'History, Romance, Drama, War & Military',
#  'Drama, Science-Fiction, Mystery & Thriller',
#  'Drama, Action & Adventure, Crime, Mystery & Thriller',
#  'Crime, Mystery & Thriller, Drama',
#  'Crime, Drama, Mystery & Thriller',
#  'Drama, Crime, Mystery & Thriller',
#  'Drama, Fantasy, Horror, Animation, Action & Adventure, Science-Fiction',
#  'Comedy, Crime',
#  'Drama, Science-Fiction, War & Military, Action & Adventure, Mystery & Thriller',
#  'Mystery & Thriller, Science-Fiction, Action & Adventure, Drama, Fantasy',
#  'Crime, Drama, Mystery & Thriller',
#  'Science-Fiction, Action & Adventure, Drama',
#  'Drama',
#  'Science-Fiction, Drama, Fantasy',
#  'Reality TV',
#  'Horror, Mystery & Thriller, Crime, Drama',
#  'Romance, Drama',
#  'Drama',
#  'Drama, Science-Fiction, Mystery & Thriller, Fantasy, Horror',
#  'Science-Fiction, Mystery & Thriller, Drama, Horror',
#  'Drama, Crime, Mystery & Thriller',
#  'Drama, Comedy, Fantasy',
#  'Mystery & Thriller, Action & Adventure, Crime, Drama, Made in Europe',
#  'Crime, Drama, Mystery & Thriller',
#  'Science-Fiction, Mystery & Thriller, Drama, Horror',
#  'Comedy, Drama, Action & Adventure',
#  'Drama, Crime',
#  'Reality TV, Romance',
#  'Science-Fiction, Drama, Comedy',
#  'Crime, Drama, Comedy, Action & Adventure',
#  'Drama, Crime, Mystery & Thriller',
#  'Animation, Action & Adventure, Fantasy, Mystery & Thriller, Science-Fiction',
#  'Comedy, Science-Fiction, Drama, Fantasy, Romance',
#  'Horror, Science-Fiction, Animation, Action & Adventure, Fantasy',
#  'Drama, Crime',
#  'Reality TV, Kids & Family',
#  'Animation, Action & Adventure, Kids & Family, Fantasy',
#  'Reality TV']

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Write Your Code here
import requests
from lxml import html

# List of IMDb URLs
urls = url_list

# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

# List to store results
results = []
ratings = []

# XPath expressions for ratings and title
rating_xpaths = [
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[2]/div/div/div[2]/div/span/span/text()',
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[1]/div/div/div[2]/div/span/span/text()'
]


# Loop through the list of URLs
for url in urls:
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()

        tree = html.fromstring(response.content)


        rating = None
        for xpath in rating_xpaths:
            rating = tree.xpath(xpath)
            if rating:
                rating = rating[0]
                break

        results.append((rating))
        ratings.append(rating)
        print(f"IMDb Rating: {rating}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        results.append(("Error fetching title", None))
        ratings.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        results.append(("Error processing title", None))
        ratings.append(None)

# Print results
for rating in results:
    if rating is not None:
        print(f" IMDb Rating: {rating}")
    else:
        print(f" IMDb Rating not available")

# Print all ratings
print("All Ratings:", ratings)
# Out:
# IMDb Rating:  8.5  (83k)
# IMDb Rating:  9.0  (94k)
# IMDb Rating:  8.4  (400k)
# IMDb Rating:  8.7  (682k)
# IMDb Rating:  9.1  (23k)
# IMDb Rating:  9.0  (83k)
# IMDb Rating:  7.4  (186k)
# IMDb Rating:  9.2  (2m)
# IMDb Rating:  8.6  (156k)
# IMDb Rating:  8.7  (149k)
# IMDb Rating:  7.2  (3k)
# IMDb Rating:  8.6  (225k)
# IMDb Rating:  6.4  (27k)
# IMDb Rating:  7.8  (25k)
# IMDb Rating:  8.2  (19k)
# IMDb Rating:  7.6  (6k)
# IMDb Rating:  8.9  (425k)
# IMDb Rating:  7.4  (32k)
# IMDb Rating:  9.1  (526k)
# IMDb Rating:  7.4  (24k)
# IMDb Rating:  8.4  (220k)
# IMDb Rating:  3.5  (80k)
# IMDb Rating:  8.4  (46k)
# IMDb Rating:  6.8  (5k)
# IMDb Rating:  8.0  (116k)
# IMDb Rating:  7.5  (128k)
# IMDb Rating:  1.9  (1k)
# IMDb Rating:  7.8  (37k)
# IMDb Rating:  7.6  (10k)
# IMDb Rating:  8.3  (2k)
# IMDb Rating:  8.7  (1m)
# IMDb Rating: []
# IMDb Rating:  9.5  (2m)
# IMDb Rating:  6.9  (2k)
# IMDb Rating:  8.2  (538k)
# IMDb Rating:  8.5  (66k)
# IMDb Rating:  6.6  (1k)
# IMDb Rating:  8.7  (99k)
# IMDb Rating:  8.0  (72k)
# IMDb Rating:  3.8
# IMDb Rating:  8.0  (100k)
# IMDb Rating:  8.0  (76k)
# IMDb Rating:  8.9  (663k)
# IMDb Rating:  8.6  (122k)
# IMDb Rating:  7.7  (10k)
# IMDb Rating:  8.4  (6k)
# IMDb Rating:  8.8  (660k)
# IMDb Rating:  3.7  (4k)
# IMDb Rating:  9.1  (12k)
# IMDb Rating:  7.6  (4k)
#  IMDb Rating:  8.5  (83k)
#  IMDb Rating:  9.0  (94k)
#  IMDb Rating:  8.4  (400k)
#  IMDb Rating:  8.7  (682k)
#  IMDb Rating:  9.1  (23k)
#  IMDb Rating:  9.0  (83k)
#  IMDb Rating:  7.4  (186k)
#  IMDb Rating:  9.2  (2m)
#  IMDb Rating:  8.6  (156k)
#  IMDb Rating:  8.7  (149k)
#  IMDb Rating:  7.2  (3k)
#  IMDb Rating:  8.6  (225k)
#  IMDb Rating:  6.4  (27k)
#  IMDb Rating:  7.8  (25k)
#  IMDb Rating:  8.2  (19k)
#  IMDb Rating:  7.6  (6k)
#  IMDb Rating:  8.9  (425k)
#  IMDb Rating:  7.4  (32k)
#  IMDb Rating:  9.1  (526k)
#  IMDb Rating:  7.4  (24k)
#  IMDb Rating:  8.4  (220k)
#  IMDb Rating:  3.5  (80k)
#  IMDb Rating:  8.4  (46k)
#  IMDb Rating:  6.8  (5k)
#  IMDb Rating:  8.0  (116k)
#  IMDb Rating:  7.5  (128k)
#  IMDb Rating:  1.9  (1k)
#  IMDb Rating:  7.8  (37k)
#  IMDb Rating:  7.6  (10k)
#  IMDb Rating:  8.3  (2k)
#  IMDb Rating:  8.7  (1m)
#  IMDb Rating: []
#  IMDb Rating:  9.5  (2m)
#  IMDb Rating:  6.9  (2k)
#  IMDb Rating:  8.2  (538k)
#  IMDb Rating:  8.5  (66k)
#  IMDb Rating:  6.6  (1k)
#  IMDb Rating:  8.7  (99k)
#  IMDb Rating:  8.0  (72k)
#  IMDb Rating:  3.8
#  IMDb Rating:  8.0  (100k)
#  IMDb Rating:  8.0  (76k)
#  IMDb Rating:  8.9  (663k)
#  IMDb Rating:  8.6  (122k)
#  IMDb Rating:  7.7  (10k)
#  IMDb Rating:  8.4  (6k)
#  IMDb Rating:  8.8  (660k)
#  IMDb Rating:  3.7  (4k)
#  IMDb Rating:  9.1  (12k)
#  IMDb Rating:  7.6  (4k)
# All Ratings: [' 8.5  (83k) ', ' 9.0  (94k) ', ' 8.4  (400k) ', ' 8.7  (682k) ', ' 9.1  (23k) ', ' 9.0  (83k) ', ' 7.4  (186k) ', ' 9.2  (2m) ', ' 8.6  (156k) ', ' 8.7  (149k) ', ' 7.2  (3k) ', ' 8.6  (225k) ', ' 6.4  (27k) ', ' 7.8  (25k) ', ' 8.2  (19k) ', ' 7.6  (6k) ', ' 8.9  (425k) ', ' 7.4  (32k) ', ' 9.1  (526k) ', ' 7.4  (24k) ', ' 8.4  (220k) ', ' 3.5  (80k) ', ' 8.4  (46k) ', ' 6.8  (5k) ', ' 8.0  (116k) ', ' 7.5  (128k) ', ' 1.9  (1k) ', ' 7.8  (37k) ', ' 7.6  (10k) ', ' 8.3  (2k) ', ' 8.7  (1m) ', [], ' 9.5  (2m) ', ' 6.9  (2k) ', ' 8.2  (538k) ', ' 8.5  (66k) ', ' 6.6  (1k) ', ' 8.7  (99k) ', ' 8.0  (72k) ', ' 3.8  ', ' 8.0  (100k) ', ' 8.0  (76k) ', ' 8.9  (663k) ', ' 8.6  (122k) ', ' 7.7  (10k) ', ' 8.4  (6k) ', ' 8.8  (660k) ', ' 3.7  (4k) ', ' 9.1  (12k) ', ' 7.6  (4k) ']

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Write Your Code here
import requests
from lxml import html

# List of IMDb URLs
urls = url_list
# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

# List to store results
age_ratings = []

# XPath expression for age rating
age_rating_xpath = '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[5]/div/text()'

# Loop through the list of URLs
for url in urls:
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()

        tree = html.fromstring(response.content)

        age_rating = tree.xpath(age_rating_xpath)
        age_rating = age_rating[0] if age_rating else None

        if age_rating in ["UA", "A", "U"]:
            age_ratings.append(age_rating)
            print(f"Age Rating: {age_rating}")
        else:
            age_ratings.append(None)
            print("Age Rating not in ['UA', 'A', 'U']")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        age_ratings.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        age_ratings.append(None)

# Print all age ratings
print("All Age Ratings:", age_ratings)
# Out:
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: A
# Age Rating: A
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: A
# Age Rating: A
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: A
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: A
# Age Rating: U
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: UA
# Age Rating: A
# Age Rating: A
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: U
# Age Rating: A
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: U
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: U
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: U
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating: A
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# Age Rating not in ['UA', 'A', 'U']
# All Age Ratings: [None, None, 'A', 'A', None, None, 'A', 'A', None, None, None, None, None, 'A', None, 'A', 'U', None, 'UA', 'A', 'A', None, None, None, 'U', 'A', None, None, None, None, None, None, 'U', None, None, None, None, None, None, None, 'U', None, 'U', None, None, None, 'A', None, None, None]

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# Write Your Code here
import requests
from lxml import html

# List of IMDb URLs
urls = url_list

# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}


retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

# List to store results
results = []
production_countries = []

# XPath expressions for production country
production_country_xpaths = [
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[6]/div/text()',
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[5]/div/text()',
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[4]/div/text()'
]

# Loop through the list of URLs
for url in urls:
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()

        tree = html.fromstring(response.content)

        production_country = None
        for xpath in production_country_xpaths:
            production_country = tree.xpath(xpath)
            if production_country:
                production_country = production_country[0].strip()
                break

        results.append(production_country)
        production_countries.append(production_country)
        print(f"Production Country: {production_country}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        results.append(None)
        production_countries.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        results.append(None)
        production_countries.append(None)

# Print results
for production_country in results:
    if production_country is not None:
        print(f"Production Country: {production_country}")
    else:
        print(f"Production Country not available")

# Print all production countries
print("All Production Countries:", production_countries)
# Out:
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: United States, United Kingdom
# Production Country: Japan
# Production Country: United States
# Production Country: Spain
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: India
# Production Country: Japan
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: India
# Production Country: United Kingdom
# Production Country: United States
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: Germany
# Production Country: India
# Production Country: United States
# Production Country: []
# Production Country: United States
# Production Country: India
# Production Country: Spain
# Production Country: India
# Production Country: Indonesia
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: United States
# Production Country: United States, Japan
# Production Country: South Korea
# Production Country: Japan
# Production Country: United Kingdom
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: India
# Production Country: India
# Production Country: United States
# Production Country: United States, United Kingdom
# Production Country: Japan
# Production Country: United States
# Production Country: Spain
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: India
# Production Country: Japan
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: India
# Production Country: United Kingdom
# Production Country: United States
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: Germany
# Production Country: India
# Production Country: United States
# Production Country: []
# Production Country: United States
# Production Country: India
# Production Country: Spain
# Production Country: India
# Production Country: Indonesia
# Production Country: India
# Production Country: United States
# Production Country: India
# Production Country: United States
# Production Country: United States
# Production Country: United States
# Production Country: United States, Japan
# Production Country: South Korea
# Production Country: Japan
# Production Country: United Kingdom
# Production Country: India
# Production Country: India
# Production Country: United States
# All Production Countries: ['India', 'India', 'United States', 'United States', 'India', 'India', 'United States', 'United States, United Kingdom', 'Japan', 'United States', 'Spain', 'United States', 'India', 'United States', 'India', 'United States', 'United States', 'India', 'Japan', 'India', 'United States', 'United States', 'India', 'United Kingdom', 'United States', 'United States', 'India', 'United States', 'Germany', 'India', 'United States', [], 'United States', 'India', 'Spain', 'India', 'Indonesia', 'India', 'United States', 'India', 'United States', 'United States', 'United States', 'United States, Japan', 'South Korea', 'Japan', 'United Kingdom', 'India', 'India', 'United States']

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
from bs4 import BeautifulSoup
import requests

# Example URL list (replace with your actual URLs)
url_list = url_list

# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

stream = []  # List to store streaming service values

# Loop through the list of URLs, up to a maximum of 50 URLs
for url in url_list:
    try:
        # Send a GET request, passing headers
        response = session.get(url, headers=headers)
        response.raise_for_status()

        # Parse the HTML content
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find the first <img> tag with class 'offer__icon'
        icon = soup.find('img', class_='offer__icon')

        # Extract the 'alt' attribute (streaming service name)
        if icon:
            alt = icon.get('alt')
            stream.append(alt)
            print(f"URL: {url}")
            print(f"Streaming Service: {alt}")
        else:
            print(f"No streaming service found for URL: {url}")
            stream.append("No streaming service found")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        stream.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        stream.append(None)

# Print all streaming service values collected
print("All Streaming Services:", stream)
# Out:
# URL: https://www.justwatch.com/in/tv-show/mirzapur
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/panchayat
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/house-of-the-dragon
# Streaming Service: Jio Cinema
# URL: https://www.justwatch.com/in/tv-show/the-boys
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/gullak
# Streaming Service: Sony Liv
# URL: https://www.justwatch.com/in/tv-show/kota-factory
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/tv-show/bridgerton
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/tv-show/game-of-thrones
# Streaming Service: Jio Cinema
# URL: https://www.justwatch.com/in/tv-show/demon-slayer-kimetsu-no-yaiba
# Streaming Service: Crunchyroll
# URL: https://www.justwatch.com/in/tv-show/shogun-2024
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/tv-show/raising-voices
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/tv-show/the-bear
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/tv-show/heeramandi
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/tv-show/dark-matter-2024
# Streaming Service: Apple TV Plus
# URL: https://www.justwatch.com/in/tv-show/apharan
# Streaming Service: Jio Cinema
# URL: https://www.justwatch.com/in/tv-show/presumed-innocent
# Streaming Service: Apple TV Plus
# URL: https://www.justwatch.com/in/tv-show/fargo
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/aashram
# Streaming Service: MX Player
# URL: https://www.justwatch.com/in/tv-show/attack-on-titan
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/sunflower-2021
# Streaming Service: Zee5
# URL: https://www.justwatch.com/in/tv-show/fallout
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/the-acolyte
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/tv-show/farzi
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/supacell
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/tv-show/the-good-doctor
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/3-body-problem
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/tv-show/bigg-boss-ott
# Streaming Service: Jio Cinema
# URL: https://www.justwatch.com/in/tv-show/evil
# Streaming Service: Jio Cinema
# URL: https://www.justwatch.com/in/tv-show/maxton-hall-the-world-between-us
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/jamnapaar
# Streaming Service: Amazon miniTV
# URL: https://www.justwatch.com/in/tv-show/stranger-things
# Streaming Service: Netflix
# No streaming service found for URL: https://www.justwatch.com/in/tv-show/from
# URL: https://www.justwatch.com/in/tv-show/breaking-bad
# Streaming Service: Netflix
# No streaming service found for URL: https://www.justwatch.com/in/tv-show/mastram
# URL: https://www.justwatch.com/in/tv-show/paperhouse
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/tv-show/asur
# Streaming Service: Jio Cinema
# URL: https://www.justwatch.com/in/tv-show/joko-anwars-nightmares-and-daydreams
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/tv-show/the-family-man
# Streaming Service: Amazon Prime Video
# URL: https://www.justwatch.com/in/tv-show/tulsa-king
# Streaming Service: Jio Cinema
# URL: https://www.justwatch.com/in/tv-show/mtv-splitsvilla
# Streaming Service: Jio Cinema
# URL: https://www.justwatch.com/in/tv-show/the-orville
# Streaming Service: Hotstar
# No streaming service found for URL: https://www.justwatch.com/in/tv-show/the-rookie
# URL: https://www.justwatch.com/in/tv-show/true-detective
# Streaming Service: Jio Cinema
# URL: https://www.justwatch.com/in/tv-show/jujutsu-kaisen
# Streaming Service: Crunchyroll
# URL: https://www.justwatch.com/in/tv-show/my-demon
# Streaming Service: Netflix
# URL: https://www.justwatch.com/in/tv-show/kaiju-no-8
# Streaming Service: Crunchyroll
# URL: https://www.justwatch.com/in/tv-show/peaky-blinders
# Streaming Service: Netflix
# No streaming service found for URL: https://www.justwatch.com/in/tv-show/bigg-boss
# URL: https://www.justwatch.com/in/tv-show/the-legend-of-hanuman
# Streaming Service: Hotstar
# URL: https://www.justwatch.com/in/tv-show/the-mole-2022
# Streaming Service: Netflix
# All Streaming Services: ['Amazon Prime Video', 'Amazon Prime Video', 'Jio Cinema', 'Amazon Prime Video', 'Sony Liv', 'Netflix', 'Netflix', 'Jio Cinema', 'Crunchyroll', 'Hotstar', 'Netflix', 'Hotstar', 'Netflix', 'Apple TV Plus', 'Jio Cinema', 'Apple TV Plus', 'Amazon Prime Video', 'MX Player', 'Amazon Prime Video', 'Zee5', 'Amazon Prime Video', 'Hotstar', 'Amazon Prime Video', 'Netflix', 'Amazon Prime Video', 'Netflix', 'Jio Cinema', 'Jio Cinema', 'Amazon Prime Video', 'Amazon miniTV', 'Netflix', 'No streaming service found', 'Netflix', 'No streaming service found', 'Netflix', 'Jio Cinema', 'Netflix', 'Amazon Prime Video', 'Jio Cinema', 'Jio Cinema', 'Hotstar', 'No streaming service found', 'Jio Cinema', 'Crunchyroll', 'Netflix', 'Crunchyroll', 'Netflix', 'No streaming service found', 'Hotstar', 'Netflix']

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Write Your Code here

import requests
from lxml import html

# List of IMDb URLs
urls = url_list

# Define headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

retry_strategy = Retry(
        total=3,  # Retry a maximum of 3 times
        backoff_factor=2,  # Exponential backoff factor
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
    )
adapter = HTTPAdapter(max_retries=retry_strategy)
session = requests.Session()
session.mount('https://', adapter)
session.mount('http://', adapter)

# List to store results
results = []
runtimes = []

# XPath expressions for runtime
runtime_xpaths = [
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[3]/div/text()',
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[4]/div/text()',
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[5]/div/text()'
    '//*[@id="base"]/div[1]/div[2]/div/div[1]/div/aside/div[1]/div[2]/div[6]/div/text()',
]

# Loop through the list of URLs
for url in urls:
    try:
        response = session.get(url, headers=headers)
        response.raise_for_status()

        tree = html.fromstring(response.content)

        runtime = None
        for xpath in runtime_xpaths:
            runtime = tree.xpath(xpath)
            if runtime:
                runtime = runtime[0]
                break

        results.append(runtime)
        runtimes.append(runtime)
        print(f"Runtime: {runtime}")

    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        results.append(None)
        runtimes.append(None)
    except Exception as e:
        print(f"Error processing URL {url}: {e}")
        results.append(None)
        runtimes.append(None)

# Print results
for runtime in results:
    if runtime is not None:
        print(f"Runtime: {runtime}")
    else:
        print(f"Runtime not available")

# Print all runtimes
print("All Runtimes:", runtimes)
# Out:
# Runtime: 50min
# Runtime: 35min
# Runtime: 59min
# Runtime: 1h 2min
# Runtime: 30min
# Runtime: 43min
# Runtime: 1h 2min
# Runtime: 58min
# Runtime: 26min
# Runtime: 59min
# Runtime: 46min
# Runtime: 34min
# Runtime: 54min
# Runtime: 52min
# Runtime: 24min
# Runtime: 42min
# Runtime: 52min
# Runtime: 43min
# Runtime: 25min
# Runtime: 38min
# Runtime: 59min
# Runtime: 36min
# Runtime: 56min
# Runtime: 52min
# Runtime: 43min
# Runtime: 56min
# Runtime: 1h 30min
# Runtime: 49min
# Runtime: 45min
# Runtime: 32min
# Runtime: 1h 1min
# Runtime: United States
# Runtime: 47min
# Runtime: 28min
# Runtime: 51min
# Runtime: 47min
# Runtime: 52min
# Runtime: 45min
# Runtime: 38min
# Runtime: 44min
# Runtime: 53min
# Runtime: 43min
# Runtime: 1h 1min
# Runtime: 24min
# Runtime: 1h 6min
# Runtime: 24min
# Runtime: 58min
# Runtime: 1h 16min
# Runtime: 21min
# Runtime: 44min
# Runtime: 50min
# Runtime: 35min
# Runtime: 59min
# Runtime: 1h 2min
# Runtime: 30min
# Runtime: 43min
# Runtime: 1h 2min
# Runtime: 58min
# Runtime: 26min
# Runtime: 59min
# Runtime: 46min
# Runtime: 34min
# Runtime: 54min
# Runtime: 52min
# Runtime: 24min
# Runtime: 42min
# Runtime: 52min
# Runtime: 43min
# Runtime: 25min
# Runtime: 38min
# Runtime: 59min
# Runtime: 36min
# Runtime: 56min
# Runtime: 52min
# Runtime: 43min
# Runtime: 56min
# Runtime: 1h 30min
# Runtime: 49min
# Runtime: 45min
# Runtime: 32min
# Runtime: 1h 1min
# Runtime: United States
# Runtime: 47min
# Runtime: 28min
# Runtime: 51min
# Runtime: 47min
# Runtime: 52min
# Runtime: 45min
# Runtime: 38min
# Runtime: 44min
# Runtime: 53min
# Runtime: 43min
# Runtime: 1h 1min
# Runtime: 24min
# Runtime: 1h 6min
# Runtime: 24min
# Runtime: 58min
# Runtime: 1h 16min
# Runtime: 21min
# Runtime: 44min
# All Runtimes: ['50min', '35min', '59min', '1h 2min', '30min', '43min', '1h 2min', '58min', '26min', '59min', '46min', '34min', '54min', '52min', '24min', '42min', '52min', '43min', '25min', '38min', '59min', '36min', '56min', '52min', '43min', '56min', '1h 30min', '49min', '45min', '32min', '1h 1min', 'United States', '47min', '28min', '51min', '47min', '52min', '45min', '38min', '44min', '53min', '43min', '1h 1min', '24min', '1h 6min', '24min', '58min', '1h 16min', '21min', '44min']

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
# Write Your Code here
# Assuming 'tv_show_names' and 'release_dates' are lists of equal length (50)
tv_show=pd.DataFrame({'Show Name': show_names, 'release_dates': release_dates,'Generes': Generes,"IMDB_ratings":ratings,"runtimes":runtimes,
              "age_ratings":age_ratings,"production_countries":production_countries,"streaming service":stream,"link":url_list})

# %%
tv_show
# Out:
#                                 Show Name release_dates  \
# 0                                Mirzapur          2024
# 1                               Panchayat          2024
# 2                     House of the Dragon          2024
# 3                                The Boys          2024
# 4                                  Gullak          2019
# 5                            Kota Factory          2024
# 6                              Bridgerton          2023
# 7                         Game of Thrones          2024
# 8          Demon Slayer: Kimetsu no Yaiba          2015
# 9                                  Shōgun          2024
# 10                         Raising Voices          2024
# 11                               The Bear          2024
# 12         Heeramandi: The Diamond Bazaar          2024
# 13                            Dark Matter          2011
# 14                                Apharan          2024
# 15                      Presumed Innocent          2024
# 16                                  Fargo          2024
# 17                                Aashram          2024
# 18                        Attack on Titan          2019
# 19                              Sunflower          2024
# 20                                Fallout          2024
# 21                            The Acolyte          2024
# 22                                  Farzi          2024
# 23                               Supacell          2023
# 24                        The Good Doctor          2015
# 25                         3 Body Problem          2024
# 26                          Bigg Boss OTT          2020
# 27                                   Evil          2024
# 28      Maxton Hall: The World Between Us          2024
# 29                              Jamnapaar          2024
# 30                        Stranger Things          2024
# 31                                   From          2018
# 32                           Breaking Bad          2024
# 33                                Mastram          2024
# 34                            Money Heist          2024
# 35        Asur: Welcome to Your Dark Side          2024
# 36  Joko Anwar's Nightmares and Daydreams          2023
# 37                         The Family Man          2024
# 38                             Tulsa King          2023
# 39                        MTV Splitsvilla          2024
# 40                            The Orville          2023
# 41                             The Rookie          2024
# 42                         True Detective          2024
# 43                         Jujutsu Kaisen          2024
# 44                               My Demon          2024
# 45                            Kaiju No. 8          2021
# 46                         Peaky Blinders          2024
# 47                              Bigg Boss          2023
# 48                  The Legend of Hanuman          2021
# 49                               The Mole          2023
#
#                                               Generes   IMDB_ratings  \
# 0   Crime, Action & Adventure, Drama, Mystery & Th...    8.5  (83k)
# 1                                       Drama, Comedy    9.0  (94k)
# 2   Romance, Action & Adventure, Drama, Fantasy, S...   8.4  (400k)
# 3   Action & Adventure, Science-Fiction, Comedy, C...   8.7  (682k)
# 4                        Kids & Family, Comedy, Drama    9.1  (23k)
# 5                                       Comedy, Drama    9.0  (83k)
# 6                                      Drama, Romance   7.4  (186k)
# 7   Action & Adventure, Drama, Fantasy, Science-Fi...     9.2  (2m)
# 8   Animation, Action & Adventure, Fantasy, Myster...   8.6  (156k)
# 9                      War & Military, Drama, History   8.7  (149k)
# 10                                              Drama     7.2  (3k)
# 11                                      Drama, Comedy   8.6  (225k)
# 12            History, Romance, Drama, War & Military    6.4  (27k)
# 13         Drama, Science-Fiction, Mystery & Thriller    7.8  (25k)
# 14  Drama, Action & Adventure, Crime, Mystery & Th...    8.2  (19k)
# 15                   Crime, Mystery & Thriller, Drama     7.6  (6k)
# 16                   Crime, Drama, Mystery & Thriller   8.9  (425k)
# 17                   Drama, Crime, Mystery & Thriller    7.4  (32k)
# 18  Drama, Fantasy, Horror, Animation, Action & Ad...   9.1  (526k)
# 19                                      Comedy, Crime    7.4  (24k)
# 20  Drama, Science-Fiction, War & Military, Action...   8.4  (220k)
# 21  Mystery & Thriller, Science-Fiction, Action & ...    3.5  (80k)
# 22                   Crime, Drama, Mystery & Thriller    8.4  (46k)
# 23         Science-Fiction, Action & Adventure, Drama     6.8  (5k)
# 24                                              Drama   8.0  (116k)
# 25                    Science-Fiction, Drama, Fantasy   7.5  (128k)
# 26                                         Reality TV     1.9  (1k)
# 27           Horror, Mystery & Thriller, Crime, Drama    7.8  (37k)
# 28                                     Romance, Drama    7.6  (10k)
# 29                                              Drama     8.3  (2k)
# 30  Drama, Science-Fiction, Mystery & Thriller, Fa...     8.7  (1m)
# 31  Science-Fiction, Mystery & Thriller, Drama, Ho...             []
# 32                   Drama, Crime, Mystery & Thriller     9.5  (2m)
# 33                             Drama, Comedy, Fantasy     6.9  (2k)
# 34  Mystery & Thriller, Action & Adventure, Crime,...   8.2  (538k)
# 35                   Crime, Drama, Mystery & Thriller    8.5  (66k)
# 36  Science-Fiction, Mystery & Thriller, Drama, Ho...     6.6  (1k)
# 37                  Comedy, Drama, Action & Adventure    8.7  (99k)
# 38                                       Drama, Crime    8.0  (72k)
# 39                                Reality TV, Romance          3.8
# 40                     Science-Fiction, Drama, Comedy   8.0  (100k)
# 41           Crime, Drama, Comedy, Action & Adventure    8.0  (76k)
# 42                   Drama, Crime, Mystery & Thriller   8.9  (663k)
# 43  Animation, Action & Adventure, Fantasy, Myster...   8.6  (122k)
# 44   Comedy, Science-Fiction, Drama, Fantasy, Romance    7.7  (10k)
# 45  Horror, Science-Fiction, Animation, Action & A...     8.4  (6k)
# 46                                       Drama, Crime   8.8  (660k)
# 47                          Reality TV, Kids & Family     3.7  (4k)
# 48  Animation, Action & Adventure, Kids & Family, ...    9.1  (12k)
# 49                                         Reality TV     7.6  (4k)
#
#          runtimes age_ratings           production_countries  \
# 0           50min        None                          India
# 1           35min        None                          India
# 2           59min           A                  United States
# 3         1h 2min           A                  United States
# 4           30min        None                          India
# 5           43min        None                          India
# 6         1h 2min           A                  United States
# 7           58min           A  United States, United Kingdom
# 8           26min        None                          Japan
# 9           59min        None                  United States
# 10          46min        None                          Spain
# 11          34min        None                  United States
# 12          54min        None                          India
# 13          52min           A                  United States
# 14          24min        None                          India
# 15          42min           A                  United States
# 16          52min           U                  United States
# 17          43min        None                          India
# 18          25min          UA                          Japan
# 19          38min           A                          India
# 20          59min           A                  United States
# 21          36min        None                  United States
# 22          56min        None                          India
# 23          52min        None                 United Kingdom
# 24          43min           U                  United States
# 25          56min           A                  United States
# 26       1h 30min        None                          India
# 27          49min        None                  United States
# 28          45min        None                        Germany
# 29          32min        None                          India
# 30        1h 1min        None                  United States
# 31  United States        None                             []
# 32          47min           U                  United States
# 33          28min        None                          India
# 34          51min        None                          Spain
# 35          47min        None                          India
# 36          52min        None                      Indonesia
# 37          45min        None                          India
# 38          38min        None                  United States
# 39          44min        None                          India
# 40          53min           U                  United States
# 41          43min        None                  United States
# 42        1h 1min           U                  United States
# 43          24min        None           United States, Japan
# 44        1h 6min        None                    South Korea
# 45          24min        None                          Japan
# 46          58min           A                 United Kingdom
# 47       1h 16min        None                          India
# 48          21min        None                          India
# 49          44min        None                  United States
#
#              streaming service  \
# 0           Amazon Prime Video
# 1           Amazon Prime Video
# 2                   Jio Cinema
# 3           Amazon Prime Video
# 4                     Sony Liv
# 5                      Netflix
# 6                      Netflix
# 7                   Jio Cinema
# 8                  Crunchyroll
# 9                      Hotstar
# 10                     Netflix
# 11                     Hotstar
# 12                     Netflix
# 13               Apple TV Plus
# 14                  Jio Cinema
# 15               Apple TV Plus
# 16          Amazon Prime Video
# 17                   MX Player
# 18          Amazon Prime Video
# 19                        Zee5
# 20          Amazon Prime Video
# 21                     Hotstar
# 22          Amazon Prime Video
# 23                     Netflix
# 24          Amazon Prime Video
# 25                     Netflix
# 26                  Jio Cinema
# 27                  Jio Cinema
# 28          Amazon Prime Video
# 29               Amazon miniTV
# 30                     Netflix
# 31  No streaming service found
# 32                     Netflix
# 33  No streaming service found
# 34                     Netflix
# 35                  Jio Cinema
# 36                     Netflix
# 37          Amazon Prime Video
# 38                  Jio Cinema
# 39                  Jio Cinema
# 40                     Hotstar
# 41  No streaming service found
# 42                  Jio Cinema
# 43                 Crunchyroll
# 44                     Netflix
# 45                 Crunchyroll
# 46                     Netflix
# 47  No streaming service found
# 48                     Hotstar
# 49                     Netflix
#
#                                                  link
# 0       https://www.justwatch.com/in/tv-show/mirzapur
# 1      https://www.justwatch.com/in/tv-show/panchayat
# 2   https://www.justwatch.com/in/tv-show/house-of-...
# 3       https://www.justwatch.com/in/tv-show/the-boys
# 4         https://www.justwatch.com/in/tv-show/gullak
# 5   https://www.justwatch.com/in/tv-show/kota-factory
# 6     https://www.justwatch.com/in/tv-show/bridgerton
# 7   https://www.justwatch.com/in/tv-show/game-of-t...
# 8   https://www.justwatch.com/in/tv-show/demon-sla...
# 9    https://www.justwatch.com/in/tv-show/shogun-2024
# 10  https://www.justwatch.com/in/tv-show/raising-v...
# 11      https://www.justwatch.com/in/tv-show/the-bear
# 12    https://www.justwatch.com/in/tv-show/heeramandi
# 13  https://www.justwatch.com/in/tv-show/dark-matt...
# 14       https://www.justwatch.com/in/tv-show/apharan
# 15  https://www.justwatch.com/in/tv-show/presumed-...
# 16         https://www.justwatch.com/in/tv-show/fargo
# 17       https://www.justwatch.com/in/tv-show/aashram
# 18  https://www.justwatch.com/in/tv-show/attack-on...
# 19  https://www.justwatch.com/in/tv-show/sunflower...
# 20       https://www.justwatch.com/in/tv-show/fallout
# 21   https://www.justwatch.com/in/tv-show/the-acolyte
# 22         https://www.justwatch.com/in/tv-show/farzi
# 23      https://www.justwatch.com/in/tv-show/supacell
# 24  https://www.justwatch.com/in/tv-show/the-good-...
# 25  https://www.justwatch.com/in/tv-show/3-body-pr...
# 26  https://www.justwatch.com/in/tv-show/bigg-boss...
# 27          https://www.justwatch.com/in/tv-show/evil
# 28  https://www.justwatch.com/in/tv-show/maxton-ha...
# 29     https://www.justwatch.com/in/tv-show/jamnapaar
# 30  https://www.justwatch.com/in/tv-show/stranger-...
# 31          https://www.justwatch.com/in/tv-show/from
# 32  https://www.justwatch.com/in/tv-show/breaking-bad
# 33       https://www.justwatch.com/in/tv-show/mastram
# 34    https://www.justwatch.com/in/tv-show/paperhouse
# 35          https://www.justwatch.com/in/tv-show/asur
# 36  https://www.justwatch.com/in/tv-show/joko-anwa...
# 37  https://www.justwatch.com/in/tv-show/the-famil...
# 38    https://www.justwatch.com/in/tv-show/tulsa-king
# 39  https://www.justwatch.com/in/tv-show/mtv-split...
# 40   https://www.justwatch.com/in/tv-show/the-orville
# 41    https://www.justwatch.com/in/tv-show/the-rookie
# 42  https://www.justwatch.com/in/tv-show/true-dete...
# 43  https://www.justwatch.com/in/tv-show/jujutsu-k...
# 44      https://www.justwatch.com/in/tv-show/my-demon
# 45    https://www.justwatch.com/in/tv-show/kaiju-no-8
# 46  https://www.justwatch.com/in/tv-show/peaky-bli...
# 47     https://www.justwatch.com/in/tv-show/bigg-boss
# 48  https://www.justwatch.com/in/tv-show/the-legen...
# 49  https://www.justwatch.com/in/tv-show/the-mole-...

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %% [markdown]
# **2. Data Filtering & Analysis:**
#
#    After scraping the data, use Pandas to perform the following tasks:
#
#    **a. Filter movies and TV shows based on specific criteria:**
#
#    ```
#       - Only include movies and TV shows released in the last 2 years (from the current date).
#       - Only include movies and TV shows with an IMDb rating of 7 or higher.
# ```

# %%
# Write Your Code here
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Movie Name            50 non-null     object
#  1   release_dates         50 non-null     object
#  2   Generes               50 non-null     object
#  3   IMDB_ratings          50 non-null     object
#  4   runtimes              50 non-null     object
#  5   age_ratings           25 non-null     object
#  6   production_countries  50 non-null     object
#  7   streaming service     50 non-null     object
#  8   link                  50 non-null     object
# dtypes: object(9)
# memory usage: 3.6+ KB

# %%
#Only include movies and TV shows released in the last 2 years (from the current date).
movies['release_dates']=movies['release_dates'].astype('int')
movies_new=movies[movies['release_dates']>2022]

tv_show['release_dates']=tv_show['release_dates'].astype('int')
tv_show_new=tv_show[tv_show['release_dates']>2022]

# %%
movies_new.head()
# Out:
#       Movie Name  release_dates  \
# 0         Munjya           2024
# 1       Aavesham           2024
# 2  Kalki 2898 AD           2024
# 3    Family Star           2024
# 5        Hit Man           2024
#
#                                              Generes  IMDB_ratings  runtimes  \
# 0                                     Comedy, Horror   7.2  (14k)    2h 3min
# 1                         Comedy, Action & Adventure   8.0  (12k)   2h 38min
# 2  Drama, Action & Adventure, Fantasy, Science-Fi...   7.9  (32k)    3h 1min
# 3         Action & Adventure, Drama, Comedy, Romance    5.2  (3k)   2h 39min
# 5                             Crime, Comedy, Romance   6.9  (61k)   1h 56min
#
#   age_ratings production_countries   streaming service  \
# 0        None                India          Bookmyshow
# 1        None                India  Amazon Prime Video
# 2        None                India          Bookmyshow
# 3        None                India  Amazon Prime Video
# 5           A        United States             Netflix
#
#                                                link
# 0         https://www.justwatch.com/in/movie/munjha
# 1  https://www.justwatch.com/in/movie/aavesham-2024
# 2      https://www.justwatch.com/in/movie/project-k
# 3    https://www.justwatch.com/in/movie/family-star
# 5        https://www.justwatch.com/in/movie/hit-man

# %%
tv_show_new.head()
# Out:
#              Show Name  release_dates  \
# 0             Mirzapur           2024
# 1            Panchayat           2024
# 2  House of the Dragon           2024
# 3             The Boys           2024
# 5         Kota Factory           2024
#
#                                              Generes   IMDB_ratings runtimes  \
# 0  Crime, Action & Adventure, Drama, Mystery & Th...    8.5  (83k)     50min
# 1                                      Drama, Comedy    9.0  (94k)     35min
# 2  Romance, Action & Adventure, Drama, Fantasy, S...   8.4  (400k)     59min
# 3  Action & Adventure, Science-Fiction, Comedy, C...   8.7  (682k)   1h 2min
# 5                                      Comedy, Drama    9.0  (83k)     43min
#
#   age_ratings production_countries   streaming service  \
# 0        None                India  Amazon Prime Video
# 1        None                India  Amazon Prime Video
# 2           A        United States          Jio Cinema
# 3           A        United States  Amazon Prime Video
# 5        None                India             Netflix
#
#                                                 link
# 0      https://www.justwatch.com/in/tv-show/mirzapur
# 1     https://www.justwatch.com/in/tv-show/panchayat
# 2  https://www.justwatch.com/in/tv-show/house-of-...
# 3      https://www.justwatch.com/in/tv-show/the-boys
# 5  https://www.justwatch.com/in/tv-show/kota-factory

# %%
movies_new["IMDB_ratings"]=movies_new["IMDB_ratings"].str.split().str[0].astype(float)
tv_show_new["IMDB_ratings"]=tv_show_new["IMDB_ratings"].str.split().str[0].astype(float)
# Out:
# <ipython-input-306-9bd15d846637>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies_new["IMDB_ratings"]=movies_new["IMDB_ratings"].str.split().str[0].astype(float)
# <ipython-input-306-9bd15d846637>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_show_new["IMDB_ratings"]=tv_show_new["IMDB_ratings"].str.split().str[0].astype(float)

# %%
#Only include movies and TV shows with an IMDb rating of 7 or higher
movies_new=movies_new[movies_new['IMDB_ratings']>=7]
tv_show_new=tv_show_new[tv_show_new['IMDB_ratings']>=7]

# %%
movies_new.head()
# Out:
#            Movie Name  release_dates  \
# 0              Munjya           2024
# 1            Aavesham           2024
# 2       Kalki 2898 AD           2024
# 6  Godzilla Minus One           2023
# 7        The Fall Guy           2024
#
#                                              Generes  IMDB_ratings  runtimes  \
# 0                                     Comedy, Horror           7.2   2h 3min
# 1                         Comedy, Action & Adventure           8.0  2h 38min
# 2  Drama, Action & Adventure, Fantasy, Science-Fi...           7.9   3h 1min
# 6  Horror, Action & Adventure, Drama, Science-Fic...           7.7   2h 5min
# 7         Romance, Action & Adventure, Comedy, Drama           7.0   2h 6min
#
#   age_ratings              production_countries   streaming service  \
# 0        None                             India          Bookmyshow
# 1        None                             India  Amazon Prime Video
# 2        None                             India          Bookmyshow
# 6        None                             Japan             Netflix
# 7        None  Canada, United States, Australia            Apple TV
#
#                                                 link
# 0          https://www.justwatch.com/in/movie/munjha
# 1   https://www.justwatch.com/in/movie/aavesham-2024
# 2       https://www.justwatch.com/in/movie/project-k
# 6  https://www.justwatch.com/in/movie/godzilla-mi...
# 7    https://www.justwatch.com/in/movie/the-fall-guy

# %%
tv_show_new.head()
# Out:
#              Show Name  release_dates  \
# 0             Mirzapur           2024
# 1            Panchayat           2024
# 2  House of the Dragon           2024
# 3             The Boys           2024
# 5         Kota Factory           2024
#
#                                              Generes  IMDB_ratings runtimes  \
# 0  Crime, Action & Adventure, Drama, Mystery & Th...           8.5    50min
# 1                                      Drama, Comedy           9.0    35min
# 2  Romance, Action & Adventure, Drama, Fantasy, S...           8.4    59min
# 3  Action & Adventure, Science-Fiction, Comedy, C...           8.7  1h 2min
# 5                                      Comedy, Drama           9.0    43min
#
#   age_ratings production_countries   streaming service  \
# 0        None                India  Amazon Prime Video
# 1        None                India  Amazon Prime Video
# 2           A        United States          Jio Cinema
# 3           A        United States  Amazon Prime Video
# 5        None                India             Netflix
#
#                                                 link
# 0      https://www.justwatch.com/in/tv-show/mirzapur
# 1     https://www.justwatch.com/in/tv-show/panchayat
# 2  https://www.justwatch.com/in/tv-show/house-of-...
# 3      https://www.justwatch.com/in/tv-show/the-boys
# 5  https://www.justwatch.com/in/tv-show/kota-factory

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %% [markdown]
#    **b. Data Analysis:**
#
#    ```
#       - Calculate the average IMDb rating for the scraped movies and TV shows.
#       - Identify the top 5 genres that have the highest number of available movies and TV shows.
#       - Determine the streaming service with the most significant number of offerings.

# %%
movies_new.describe()
# Out:
#        release_dates  IMDB_ratings
# count      23.000000     23.000000
# mean     2023.869565      7.856522
# std         0.344350      0.573527
# min      2023.000000      7.000000
# 25%      2024.000000      7.300000
# 50%      2024.000000      7.900000
# 75%      2024.000000      8.300000
# max      2024.000000      8.900000

# %%
tv_show_new.describe()
# Out:
#        release_dates  IMDB_ratings
# count      34.000000     34.000000
# mean     2023.882353      8.276471
# std         0.327035      0.596992
# min      2023.000000      7.200000
# 25%      2024.000000      7.725000
# 50%      2024.000000      8.400000
# 75%      2024.000000      8.700000
# max      2024.000000      9.500000

# %%
# Write Your Code here
print(f'average IMDb rating for moviews: {movies_new["IMDB_ratings"].mean()}')
print(f'average IMDb rating for tv shows: {tv_show_new["IMDB_ratings"].mean()}')
# Out:
# average IMDb rating for moviews: 7.856521739130436
# average IMDb rating for tv shows: 8.276470588235295

# %% [markdown]
# ## **Analyzing Top Genres**

# %%
movies.head(5)
# Out:
#                          Movie Name  release_dates  \
# 0                            Munjya           2024
# 1                          Aavesham           2024
# 2                     Kalki 2898 AD           2024
# 3                       Family Star           2024
# 4  The Gangster, the Cop, the Devil           2019
#
#                                              Generes  IMDB_ratings  runtimes  \
# 0                                     Comedy, Horror   7.2  (14k)    2h 3min
# 1                         Comedy, Action & Adventure   8.0  (12k)   2h 38min
# 2  Drama, Action & Adventure, Fantasy, Science-Fi...   7.9  (32k)    3h 1min
# 3         Action & Adventure, Drama, Comedy, Romance    5.2  (3k)   2h 39min
# 4      Mystery & Thriller, Action & Adventure, Crime   6.9  (24k)   1h 50min
#
#   age_ratings production_countries   streaming service  \
# 0        None                India          Bookmyshow
# 1        None                India  Amazon Prime Video
# 2        None                India          Bookmyshow
# 3        None                India  Amazon Prime Video
# 4        None          South Korea      Lionsgate Play
#
#                                                 link
# 0          https://www.justwatch.com/in/movie/munjha
# 1   https://www.justwatch.com/in/movie/aavesham-2024
# 2       https://www.justwatch.com/in/movie/project-k
# 3     https://www.justwatch.com/in/movie/family-star
# 4  https://www.justwatch.com/in/movie/the-gangste...

# %%
# Write Your Code here
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Concatenate all genres into a single string
genres_corpus = ' '.join(movies['Generes'].dropna())

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(genres_corpus)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Genres for Movies')
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Concatenate all genres into a single string
genres_corpus = ' '.join(tv_show['Generes'].dropna())

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(genres_corpus)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Tv_show_genres')
plt.show()

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %%
# Write Your Code here
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt



# Concatenate all streaming service into a single string
streaming_corpus = ' '.join(movies['streaming service'].dropna())

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(streaming_corpus)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Streaming for movies')
plt.show()

# %%
# Import necessary libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Concatenate all streaming service into a single string
streaming_corpus = ' '.join(tv_show['streaming service'].dropna())

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(streaming_corpus)

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Streaming for tv_shows')
plt.show()

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
#saving final dataframe as Final Data in csv format

movies.to_csv('movies.csv', index=False)
tv_show.to_csv('tv_shows.csv', index=False)

# %%
#saving filter data as Filter Data in csv format

movies_new.to_csv('movies_filter.csv', index=False)
tv_show_new.to_csv('tv_shows_filter.csv', index=False)

# %% [markdown]
# # **Dataset Drive Link (View Access with Anyone) -**

# %% [markdown]
# https://drive.google.com/file/d/1OHHUPjuwFj8ahJJ0ArCeFX8SVEboB8tC/view?usp=drive_link,
#
# https://drive.google.com/file/d/1hIyty60DnA3bvg6aJxaE6hEU2xMCMokh/view?usp=drive_link,
#
# https://drive.google.com/file/d/1lfqDH77RQE0CYuIhaH5xPcjc3v1rKAcM/view?usp=drive_link,
#
# https://drive.google.com/file/d/1-Cgvvb7AiThHa9JgYZxe_TSX_R3eKJoc/view?usp=drive_link

# %% [markdown]
# # ***Congratulations!!! You have completed your Assignment.***
